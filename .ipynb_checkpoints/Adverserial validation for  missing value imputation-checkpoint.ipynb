# 34        2.0   5.0
# 28        2.0   7.0
# 18        2.0   4.0
# 25        8.0   5.0
# 16       10.0  19.0
# 17        4.0   8.0
# 2         5.0   5.0
# 3         6.0   5.0
# 4         3.0  11.0
# 5         2.0   4.0
# 6        43.0  45.0
# 7         3.0   9.0
# 8         2.0   5.0
# 1         2.0   9.0
# 10        4.0   9.0
# 11        5.0  14.0
# ...       ...   ...
# 360419    2.0  18.0
# 360427    5.0   9.0
# 360421    2.0  11.0
# 360422    2.0  11.0
# 360423  121.0  14.0
# 360424    3.0  12.0
# 360425   50.0   NaN
# 360426    2.0  10.0
# 360413    3.0   7.0
# 360420    2.0   2.0
# 360412   12.0   8.0
# 360403   85.0   2.0
# 360410    2.0   4.0
# 360428   19.0  18.0
# 360395    2.0   6.0
# 360396    NaN   NaN
# 360397    4.0  15.0
# 360398    4.0  12.0
# 360399   62.0   8.0
# 360400    2.0  13.0
# 360401   15.0  12.0
# 360402   68.0   7.0
# 360404    3.0   8.0
# 360405    2.0   7.0
# 360406   95.0  18.0
# 360407    NaN   NaN
# 360408   80.0  15.0
# 360409    2.0  17.0
# 360411   47.0  11.0
# 360429    2.0   8.0
#
# [360430 rows x 8 columns]

# %%
beijing_grid_sta=pd.read_csv(path+"Beijing_historical_meo_grid.csv")
beijing_grid_sta.sort_values(by='utc_time')
# Out:
#               stationName  longitude  latitude             utc_time  \
# 0        beijing_grid_000      115.0      39.0  2017-01-01 00:00:00
# 430      beijing_grid_430      117.0      40.0  2017-01-01 00:00:00
# 431      beijing_grid_431      117.0      40.1  2017-01-01 00:00:00
# 432      beijing_grid_432      117.0      40.2  2017-01-01 00:00:00
# 433      beijing_grid_433      117.0      40.3  2017-01-01 00:00:00
# 434      beijing_grid_434      117.0      40.4  2017-01-01 00:00:00
# 435      beijing_grid_435      117.0      40.5  2017-01-01 00:00:00
# 436      beijing_grid_436      117.0      40.6  2017-01-01 00:00:00
# 429      beijing_grid_429      117.0      39.9  2017-01-01 00:00:00
# 437      beijing_grid_437      117.0      40.7  2017-01-01 00:00:00
# 439      beijing_grid_439      117.0      40.9  2017-01-01 00:00:00
# 440      beijing_grid_440      117.0      41.0  2017-01-01 00:00:00
# 441      beijing_grid_441      117.1      39.0  2017-01-01 00:00:00
# 442      beijing_grid_442      117.1      39.1  2017-01-01 00:00:00
# 443      beijing_grid_443      117.1      39.2  2017-01-01 00:00:00
# 444      beijing_grid_444      117.1      39.3  2017-01-01 00:00:00
# 445      beijing_grid_445      117.1      39.4  2017-01-01 00:00:00
# 438      beijing_grid_438      117.0      40.8  2017-01-01 00:00:00
# 446      beijing_grid_446      117.1      39.5  2017-01-01 00:00:00
# 428      beijing_grid_428      117.0      39.8  2017-01-01 00:00:00
# 426      beijing_grid_426      117.0      39.6  2017-01-01 00:00:00
# 410      beijing_grid_410      116.9      40.1  2017-01-01 00:00:00
# 411      beijing_grid_411      116.9      40.2  2017-01-01 00:00:00
# 412      beijing_grid_412      116.9      40.3  2017-01-01 00:00:00
# 413      beijing_grid_413      116.9      40.4  2017-01-01 00:00:00
# 437            -5.69    963.19     59.58           28.56            1.12
# 439            -5.79    953.41     56.45            9.08            3.06
# 440            -5.80    951.78     55.93            8.03            3.39
# 441            -3.97   1025.96     86.81          193.65            5.21
# 442            -4.10   1025.95     86.94          192.87            4.83
# 443            -4.50   1025.92     87.32          189.55            3.68
# 444            -4.89   1025.89     87.71          183.26            2.55
# 445            -5.40   1025.92     87.13          200.04            1.41
# 438            -5.74    958.30     58.02           14.27            2.06
# 446            -5.91   1025.96     86.55          262.47            0.83
# 428            -6.23   1025.23     79.78          289.51            3.02
# 426            -6.04   1026.34     85.20          302.63            1.35
# 410            -6.06   1018.68     66.85          230.25            2.17
# 411            -5.94   1013.54     64.91          216.73            1.88
# 412            -5.73   1006.69     63.95          216.19            1.61
# 413            -5.47    998.98     63.48          225.99            1.34
# 414            -5.41    989.12     63.42          248.53            1.04
# 415            -5.76    974.93     64.15          300.44            1.08
# 416            -6.11    960.74     64.88          328.59            1.73
# 427            -6.25   1025.87     83.66          295.76            2.37
# 417            -6.10    954.94     62.11          343.43            2.23
# ...              ...       ...       ...             ...             ...
# 7034289        28.40   1001.63     13.02          220.35           21.25
# 7034290        28.19   1000.95     13.43          215.48           20.01
# 7034291        27.98   1000.27     13.84          210.02           18.94
# 7034292        27.57    996.68     14.04          202.48           16.33
# 7034293        27.06    991.62     14.12          190.68           13.29
# 7034294        26.58    985.02     14.20          176.23           10.95
# 7034295        26.16    975.33     14.26          162.42            8.98
# 7034288        28.56   1002.35     12.61          223.52           21.91
# 7034278        25.35    934.87     12.52          242.60           12.86
# 7034277        25.57    939.23     12.47          233.35            7.80
# 7034276        25.72    944.31     12.75          199.09            5.47
# 7034259        23.68    911.02     13.68          251.49           24.94
# 7034260        22.64    900.70     14.89          252.64           26.77
# 7034261        21.59    890.38     16.09          253.64           28.60
# 7034262        20.72    885.39     17.91          253.52           27.66
# 7034263        19.85    880.41     19.73          253.39           26.72
# 7034264        19.56    878.75     20.34          253.35           26.41
# 7034265        28.86   1003.23     11.86          227.61           22.76
# 7034266        28.80   1002.91     11.99          226.51           22.52
# 7034267        28.64   1001.96     12.37          223.11           21.85
# 7034268        28.48   1001.02     12.75          219.50           21.27
# 7034269        28.30   1000.01     13.06          214.29           20.02
# 7034270        28.11    999.01     13.38          208.44           18.96
# 7034271        27.68    992.84     13.45          201.11           16.46
# 7034272        27.13    984.09     13.39          190.22           13.52
# 7034273        26.63    974.13     13.31          178.23           11.06
# 7034274        26.26    961.76     13.18          169.77            8.50
# 7034275        25.88    949.39     13.04          154.77            6.29
# 7034257        24.99    923.43     12.38          257.61           17.49
# 7034705        22.73    942.95     21.78          215.27           18.91
#
# [7034706 rows x 9 columns]

# %% [markdown]
# #### ADD location for the AQI station

# %%
beijingAqCsv_sta = pd.read_csv('Beijing_AirQuality_Stations.csv')

# %%
location_beijin={}
for i in range(0,len(beijingAqCsv_sta)):
    temp=beijingAqCsv_sta.iloc[i,:]
    if temp['Pollutant Species'] in list(beji_aqi_summary.groupby(["stationId"]).groups.keys()):
# 13        2.0   8.0    39.824    116.146
# 14        2.0  49.0    40.365    115.988
# 15        8.0  15.0    39.954    116.349
# 16       10.0  19.0    39.937    116.106
# 17        4.0   8.0    40.127    116.655
# 18        2.0   4.0    40.328    116.628
# 19        4.0  11.0    39.939    116.483
# 20        7.0   5.0    39.878    116.352
# 21        6.0   7.0    39.987    116.287
# 22        2.0   7.0    39.929    116.339
# 23       12.0  12.0    39.876    116.394
# 24        6.0  12.0    39.712    116.783
# 25        8.0   5.0    40.002    116.207
# 26        2.0   5.0    39.899    116.395
# 27        3.0  14.0    39.856    116.368
# 28        2.0   7.0    39.929    116.417
# 29        6.0  18.0    40.292    116.220
# ...       ...   ...       ...        ...
# 360400    2.0  13.0    39.939    116.483
# 360401   15.0  12.0    39.929    116.417
# 360402   68.0   7.0    40.328    116.628
# 360403   85.0   2.0    40.143    117.100
# 360404    3.0   8.0    39.987    116.287
# 360405    2.0   7.0    39.914    116.184
# 360406   95.0  18.0    39.824    116.146
# 360407    NaN   NaN    40.002    116.207
# 360408   80.0  15.0    40.127    116.655
# 360409    2.0  17.0    39.954    116.349
# 360410    2.0   4.0    40.090    116.174
# 360411   47.0  11.0    39.520    116.300
# 360412   12.0   8.0    40.453    115.972
# 360413    3.0   7.0    40.370    116.832
# 360414   64.0   6.0    40.292    116.220
# 360415   47.0   7.0    39.937    116.106
# 360416   98.0   7.0    40.499    116.911
# 360417    2.0  10.0    39.982    116.397
# 360418    2.0  12.0    39.876    116.394
# 360419    2.0  18.0    39.856    116.368
# 360420    2.0   2.0    39.886    116.407
# 360421    2.0  11.0    39.718    116.404
# 360422    2.0  11.0    39.742    116.136
# 360423  121.0  14.0    40.100    117.120
# 360424    3.0  12.0    39.863    116.279
# 360425   50.0   NaN    39.580    116.000
# 360426    2.0  10.0    39.937    116.461
# 360427    5.0   9.0    39.795    116.506
# 360428   19.0  18.0    39.886    116.663
# 360429    2.0   8.0    39.929    116.339
#
# [360430 rows x 10 columns]

# %%
#left=beijing_grid_sta.drop(contaniner_1)
#right=beji_aqi_summary_copy.drop(contaniner_2)
#pd.merge(left, right, how='left', on=["utc_time"])

# %% [markdown]
# # Level one adverserial detection:
# 1.just use AQI information
# 2.encode the other features NAN to 9999

# %% [markdown]
# ### drop the all NAN row ( the feature of target value)

# %%
beji_aqi_summary_copy=beji_aqi_summary.copy()

# %%
true_false_table=(beji_aqi_summary['PM2.5'].isnull()) * \
(beji_aqi_summary['PM10'].isnull()) * \
(beji_aqi_summary['NO2'].isnull()) * \
(beji_aqi_summary['CO'].isnull()) * \
(beji_aqi_summary['O3'].isnull()) * \
(beji_aqi_summary['SO2'].isnull())
# Out:
# /home/paslab/.local/lib/python3.5/site-packages/pandas/core/computation/expressions.py:179: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   .format(op=op_str, alt_op=unsupported[op_str]
# 6513      NaN  11.0    39.929    116.339
# 6514     46.0   NaN    39.987    116.287
# 6519     44.0   7.0    39.863    116.279
# 6546     26.0   6.0    39.863    116.279
# 6549     24.0   8.0    39.987    116.287
# ...       ...   ...       ...        ...
# 359291   94.0   8.0    39.886    116.407
# 359297   85.0   6.0    39.899    116.395
# 359298    NaN   5.0    40.365    115.988
# 359309   99.0  11.0    40.328    116.628
# 359325   97.0  10.0    40.328    116.628
# 359331  117.0   7.0    40.292    116.220
# 359336  124.0   5.0    40.365    115.988
# 359344  108.0   8.0    39.886    116.407
# 359352  124.0   7.0    40.292    116.220
# 359365   97.0  11.0    40.328    116.628
# 359366  126.0   5.0    40.365    115.988
# 359376  116.0   8.0    39.886    116.407
# 359390   86.0  11.0    40.328    116.628
# 359401  115.0   8.0    39.886    116.407
# 359405  117.0   7.0    39.863    116.279
# 359416   99.0   7.0    39.886    116.407
# 359434   71.0   9.0    40.328    116.628
# 359436   62.0  13.0    40.127    116.655
# 359453   73.0   7.0    40.328    116.628
# 359465   93.0   5.0    40.217    116.230
# 359474   41.0  12.0    40.127    116.655
# 359477   71.0   6.0    39.886    116.407
# 359487   66.0   6.0    40.328    116.628
# 359518   60.0   6.0    39.886    116.407
# 359530   33.0   8.0    39.886    116.407
# 359552   57.0   7.0    40.328    116.628
# 359563   10.0  11.0    39.886    116.407
# 359589   53.0   9.0    40.328    116.628
# 360268  138.0  11.0    39.914    116.184
# 360299  129.0  14.0    39.937    116.461
#
# [4824 rows x 10 columns]

# %% [markdown]
# ### Labeling

# %%
beji_aqi_summary_copy["test"]=0
beji_aqi_summary_copy.loc[beji_aqi_summary_copy["PM2.5"].isnull(),"test"]=1

# %%
beji_aqi_summary_copy.loc[beji_aqi_summary_copy["PM2.5"].isnull()]
# Out:
#                 stationId             utc_time  PM2.5   PM10    NO2   CO  \
# 1535          guanyuan_aq  2017-01-03 09:00:00    NaN  404.0  186.0  NaN
# 1568          guanyuan_aq  2017-01-03 10:00:00    NaN  501.0  207.0  7.1
# 1598          guanyuan_aq  2017-01-03 11:00:00    NaN  547.0  202.0  7.5
# 1637          guanyuan_aq  2017-01-03 12:00:00    NaN  594.0  201.0  7.7
# 1647          guanyuan_aq  2017-01-03 13:00:00    NaN  631.0  197.0  8.1
# 1710          guanyuan_aq  2017-01-03 14:00:00    NaN  657.0  189.0  8.2
# 1716          guanyuan_aq  2017-01-03 15:00:00    NaN  662.0  187.0  8.4
# 1778          guanyuan_aq  2017-01-03 16:00:00    NaN  813.0  186.0  0.9
# 1786          guanyuan_aq  2017-01-03 17:00:00    NaN  787.0  180.0  9.8
# 1831          guanyuan_aq  2017-01-03 18:00:00    NaN  783.0  169.0  9.7
# 1861          guanyuan_aq  2017-01-03 19:00:00    NaN  746.0  164.0  9.7
# 1915          guanyuan_aq  2017-01-03 20:00:00    NaN  600.0  183.0  9.8
# 1957          guanyuan_aq  2017-01-03 21:00:00    NaN  535.0  207.0  9.2
# 1979          guanyuan_aq  2017-01-03 22:00:00    NaN  420.0  190.0  7.8
# 359434   71.0   9.0    40.328    116.628     1
# 359436   62.0  13.0    40.127    116.655     1
# 359453   73.0   7.0    40.328    116.628     1
# 359465   93.0   5.0    40.217    116.230     1
# 359474   41.0  12.0    40.127    116.655     1
# 359477   71.0   6.0    39.886    116.407     1
# 359487   66.0   6.0    40.328    116.628     1
# 359518   60.0   6.0    39.886    116.407     1
# 359530   33.0   8.0    39.886    116.407     1
# 359552   57.0   7.0    40.328    116.628     1
# 359563   10.0  11.0    39.886    116.407     1
# 359589   53.0   9.0    40.328    116.628     1
# 360268  138.0  11.0    39.914    116.184     1
# 360299  129.0  14.0    39.937    116.461     1
#
# [4824 rows x 11 columns]

# %% [markdown]
# ### Start preprocess and detection

# %%
import re
def year(x):
    listofx=re.split('\-| |:',x)
    return float(listofx[0])
def month(x):
    listofx=re.split('\-| |:',x)
    return float(listofx[1])
def date(x):
    listofx=re.split('\-| |:',x)
    return float(listofx[2])
def hour(x):
    listofx=re.split('\-| |:',x)
    return float(listofx[3])
beji_aqi_summary_copy["year"]=beji_aqi_summary_copy["utc_time"].apply(lambda x:year(str(x)))
beji_aqi_summary_copy["month"]=beji_aqi_summary_copy["utc_time"].apply(lambda x:month(str(x)))
beji_aqi_summary_copy["date"]=beji_aqi_summary_copy["utc_time"].apply(lambda x:date(str(x)))
beji_aqi_summary_copy["hour"]=beji_aqi_summary_copy["utc_time"].apply(lambda x:hour(str(x)))

# %%
beji_aqi_summary_copy.tail()
# Out:
#               stationId             utc_time  PM2.5   PM10    NO2   CO    O3  \
# 360425       liulihe_aq  2018-03-31 15:00:00  136.0  204.0   61.0  1.1  50.0
# 360426  nongzhanguan_aq  2018-03-31 15:00:00  148.0  200.0  161.0  1.7   2.0
# 360427      yizhuang_aq  2018-03-31 15:00:00  137.0  192.0  166.0  1.6   5.0
# 360428      tongzhou_aq  2018-03-31 15:00:00  197.0  355.0  139.0  1.3  19.0
# 360429      guanyuan_aq  2018-03-31 15:00:00  139.0  191.0  151.0  2.1   2.0
#
#          SO2  latitude  longitude  test    year  month  date  hour
# 360425   NaN    39.580    116.000     0  2018.0    3.0  31.0  15.0
# 360426  10.0    39.937    116.461     0  2018.0    3.0  31.0  15.0
# 360427   9.0    39.795    116.506     0  2018.0    3.0  31.0  15.0
# 360428  18.0    39.886    116.663     0  2018.0    3.0  31.0  15.0
# 360429   8.0    39.929    116.339     0  2018.0    3.0  31.0  15.0

# %%
beji_aqi_summary_copy.columns
# Out:
# Index(['stationId', 'utc_time', 'PM2.5', 'PM10', 'NO2', 'CO', 'O3', 'SO2',
#        'latitude', 'longitude', 'test', 'year', 'month', 'date', 'hour'],
#       dtype='object')

# %%
#col=list(beji_aqi_summary_copy.columns).remove('PM2.5')

# %%
beji_aqi_summary_copy=beji_aqi_summary_copy.fillna(9999).copy()

# %%
train_cv=beji_aqi_summary_copy.loc[beji_aqi_summary_copy['test']==0,:].copy()
test_cv=beji_aqi_summary_copy.loc[beji_aqi_summary_copy['test']==1,:].copy()

# %%
len(beji_aqi_summary_copy)
# Out:
# 341795

# %%
train_cv=train_cv.drop(["PM2.5"],axis=1)
test_cv=test_cv.drop(["PM2.5"],axis=1)

# %%
train_cv.columns
# Out:
# Index(['stationId', 'utc_time', 'PM10', 'NO2', 'CO', 'O3', 'SO2', 'latitude',
#        'longitude', 'test', 'year', 'month', 'date', 'hour'],
#       dtype='object')

# %%
col=['year', 'month', 'date', 'hour', 'PM10', 'NO2', 'CO', 'O3', 'SO2', 'latitude',
       'longitude']

# %%
X_train=train_cv[col]
X_test=test_cv[col]
y=pd.concat([train_cv.test,test_cv.test])
data_cv = pd.concat([X_train, X_test])
data_cv.reset_index( inplace = True, drop = True )
y.reset_index( inplace = True, drop = True )
x=data_cv

# %%
predictions = np.zeros( y.shape )
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation as CV
cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)

clf=LogisticRegression()

for f, ( train_index, test_index ) in enumerate( cv ):
    
    print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
    x_train_adcv = x.iloc[train_index]
    x_test_adcv = x.iloc[test_index]
    y_train_adcv = y.iloc[train_index]
    y_test_adcv = y.iloc[test_index]
    
    clf.fit( x_train_adcv.values, y_train_adcv.values )
    
    p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
    auc = roc_auc_score( y_test_adcv, p )
    logloss=log_loss(y_test_adcv,p)
    print ("# AUC: {:.2%}\n".format( auc )	)
    print ("# log_loss: {}\n".format( logloss )	)
    
    predictions[ test_index ] = p
# Out:
# # fold 1
# # AUC: 62.32%
#
# # log_loss: 0.07262401903491571
#
# # fold 2
# # AUC: 65.66%
#
# # log_loss: 0.07198214782564609
#
# # fold 3
# # AUC: 66.36%
#
# # log_loss: 0.07170971218349632
#
# # fold 4
# # AUC: 65.81%
#
# # log_loss: 0.07180227036302071
#
# # fold 5
# # AUC: 67.49%
#
# # log_loss: 0.07139001282290887
#
# # fold 6
# # AUC: 64.24%
#
# # log_loss: 0.07208713379759485
#
# # fold 7
# # AUC: 66.17%
#
# # log_loss: 0.07151492633896017
#
# # fold 8
# # AUC: 65.24%
#
# # log_loss: 0.07168975398927943
#
# # fold 9
# # AUC: 67.44%
#
# # log_loss: 0.07100533803922678
#
# # fold 10
# # AUC: 65.39%
#
# # log_loss: 0.07186449863452872

# %% [markdown]
# The importance of the feature:(more important means it let the data's distribution more non-uniform)

# %%
plt.clf()
plt.plot(clf.coef_.tolist()[0])
plt.ylim((-1,1))
plt.show()

# %%
clf.coef_.tolist()[0]
# Out:
# [0.0033923131141826574,
#  0.050974129247011994,
#  -0.00033555621527181967,
#  -0.038492277955959886,
#  5.758043984904923e-05,
#  9.294092579446751e-05,
#  6.334741114652572e-05,
#  6.815299575917284e-05,
#  8.917429716897549e-05,
#  -0.049249485647623326,
#  -0.08002929096363785]

# %%
X_train.columns
# Out:
# Index(['year', 'month', 'date', 'hour', 'PM10', 'NO2', 'CO', 'O3', 'SO2',
#        'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# Seems 1, 3, 9,10(start from 0) thats is month , hour ,latitude, longitude, effect most

# %% [markdown]
# #### change to random forest for stronger classification, more strict validation

# %%
from sklearn.ensemble import RandomForestClassifier as RF
clf = RF( n_estimators =100,n_jobs=-1,random_state=42)

# %%
predictions = np.zeros( y.shape )
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation as CV
cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)


for f, ( train_index, test_index ) in enumerate( cv ):
    
    print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
    x_train_adcv = x.iloc[train_index]
    x_test_adcv = x.iloc[test_index]
    y_train_adcv = y.iloc[train_index]
    y_test_adcv = y.iloc[test_index]
    
    clf.fit( x_train_adcv.values, y_train_adcv.values )
    
    p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
    auc = roc_auc_score( y_test_adcv, p )
    logloss=log_loss(y_test_adcv,p)
    print ("# AUC: {:.2%}\n".format( auc )	)
    print ("# log_loss: {}\n".format( logloss )	)
    
    predictions[ test_index ] = p
# Out:
# # fold 1
# # AUC: 93.70%
#
# # log_loss: 0.05999968518363067
#
# # fold 2
# # AUC: 92.78%
#
# # log_loss: 0.0676170318936461
#
# # fold 3
# # AUC: 94.50%
#
# # log_loss: 0.053288501050232945
#
# # fold 4
# # AUC: 93.83%
#
# # log_loss: 0.05827165796237883
#
# # fold 5
# # AUC: 93.38%
#
# # log_loss: 0.06108713790654841
#
# # fold 6
# # AUC: 93.83%
#
# # log_loss: 0.0587130152740289
#
# # fold 7
# # AUC: 93.15%
#
# # log_loss: 0.06253561398609991
#
# # fold 8
# # AUC: 93.56%
#
# # log_loss: 0.060372850654274376
#
# # fold 9
# # AUC: 93.46%
#
# # log_loss: 0.061624431455197366
#
# # fold 10
# # AUC: 93.63%
#
# # log_loss: 0.0604551465698867

# %% [markdown]
# OOps!! it's  not good.....

# %%
plt.clf()
plt.figure(figsize=(20,10))
plt.title("Feature importances")
plt.xticks(range(X_train.shape[1]), X_train.columns.values)
plt.bar(range(X_train.shape[1]), clf.feature_importances_,
       color="r", align="center")
#plt.plot(clf.feature_importances_)
plt.show()

# %% [markdown]
# #### drop out the latitude and longitude

# %%
col=['year', 'month', 'date', 'hour', 'PM10', 'NO2', 'CO', 'O3', 'SO2']

# %%
X_train=train_cv[col]
X_test=test_cv[col]
y=pd.concat([train_cv.test,test_cv.test])
data_cv = pd.concat([X_train, X_test])
data_cv.reset_index( inplace = True, drop = True )
y.reset_index( inplace = True, drop = True )
x=data_cv

# %%
predictions = np.zeros( y.shape )
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation as CV
cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)

clf=LogisticRegression()

for f, ( train_index, test_index ) in enumerate( cv ):
    
    print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
    x_train_adcv = x.iloc[train_index]
    x_test_adcv = x.iloc[test_index]
    y_train_adcv = y.iloc[train_index]
    y_test_adcv = y.iloc[test_index]
    
    clf.fit( x_train_adcv.values, y_train_adcv.values )
    
    p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
    auc = roc_auc_score( y_test_adcv, p )
    logloss=log_loss(y_test_adcv,p)
    print ("# AUC: {:.2%}\n".format( auc )	)
    print ("# log_loss: {}\n".format( logloss )	)
    
    predictions[ test_index ] = p
# Out:
# # fold 1
# # AUC: 62.30%
#
# # log_loss: 0.072623685564572
#
# # fold 2
# # AUC: 65.65%
#
# # log_loss: 0.07198668347671634
#
# # fold 3
# # AUC: 66.27%
#
# # log_loss: 0.07173976094475484
#
# # fold 4
# # AUC: 65.70%
#
# # log_loss: 0.07182169834336558
#
# # fold 5
# # AUC: 67.53%
#
# # log_loss: 0.07138059460120186
#
# # fold 6
# # AUC: 64.28%
#
# # log_loss: 0.07207952798595493
#
# # fold 7
# # AUC: 66.15%
#
# # log_loss: 0.07152033989989595
#
# # fold 8
# # AUC: 65.28%
#
# # log_loss: 0.07169653509881338
#
# # fold 9
# # AUC: 67.30%
#
# # log_loss: 0.07103330278657118
#
# # fold 10
# # AUC: 65.24%
#
# # log_loss: 0.07188852650938826

# %% [markdown]
# Not significant for logistic regression

# %%
clf = RF( n_estimators =100,n_jobs=-1,random_state=42)

# %%
predictions = np.zeros( y.shape )
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation as CV
cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)


for f, ( train_index, test_index ) in enumerate( cv ):
    
    print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
    x_train_adcv = x.iloc[train_index]
    x_test_adcv = x.iloc[test_index]
    y_train_adcv = y.iloc[train_index]
    y_test_adcv = y.iloc[test_index]
    
    clf.fit( x_train_adcv.values, y_train_adcv.values )
    
    p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
    auc = roc_auc_score( y_test_adcv, p )
    logloss=log_loss(y_test_adcv,p)
    print ("# AUC: {:.2%}\n".format( auc )	)
    print ("# log_loss: {}\n".format( logloss )	)
    
    predictions[ test_index ] = p
# Out:
# # fold 1
# # AUC: 88.57%
#
# # log_loss: 0.0904946642096241
#
# # fold 2
# # AUC: 87.88%
#
# # log_loss: 0.09515276602358394
#
# # fold 3
# # AUC: 89.18%
#
# # log_loss: 0.08566125633406085
#
# # fold 4
# # AUC: 86.81%
#
# # log_loss: 0.09973419793792108
#
# # fold 5
# # AUC: 89.75%
#
# # log_loss: 0.08095779926143894
#
# # fold 6
# # AUC: 87.15%
#
# # log_loss: 0.09536109133320417
#
# # fold 7
# # AUC: 86.95%
#
# # log_loss: 0.09937557155524049
#
# # fold 8
# # AUC: 88.01%
#
# # log_loss: 0.09365934963134624
#
# # fold 9
# # AUC: 89.46%
#
# # log_loss: 0.08379338332289059
#
# # fold 10
# # AUC: 87.31%
#
# # log_loss: 0.0983823095987904

# %%
plt.clf()
plt.figure(figsize=(20,10))
plt.title("Feature importances")
plt.xticks(range(X_train.shape[1]), col)
plt.bar(range(X_train.shape[1]), clf.feature_importances_,
       color="r", align="center")
#plt.plot(clf.feature_importances_)
plt.show()

# 8260  23.0    39.939    116.483     0  2018.0    3.0  30.0  20.0
# 8261  22.0    39.939    116.483     0  2018.0    3.0  30.0  21.0
# 8262  20.0    39.939    116.483     0  2018.0    3.0  30.0  22.0
# 8263  22.0    39.939    116.483     0  2018.0    3.0  30.0  23.0
# 8264  22.0    39.939    116.483     0  2018.0    3.0  31.0   0.0
# 8265  32.0    39.939    116.483     0  2018.0    3.0  31.0   1.0
# 8266  32.0    39.939    116.483     0  2018.0    3.0  31.0   2.0
# 8267  25.0    39.939    116.483     0  2018.0    3.0  31.0   3.0
# 8268  20.0    39.939    116.483     0  2018.0    3.0  31.0   4.0
# 8269  19.0    39.939    116.483     0  2018.0    3.0  31.0   5.0
# 8270  16.0    39.939    116.483     0  2018.0    3.0  31.0   6.0
# 8271  15.0    39.939    116.483     0  2018.0    3.0  31.0   7.0
# 8272  14.0    39.939    116.483     0  2018.0    3.0  31.0   8.0
# 8273  13.0    39.939    116.483     0  2018.0    3.0  31.0   9.0
# 8274  12.0    39.939    116.483     0  2018.0    3.0  31.0  10.0
# 8275  14.0    39.939    116.483     0  2018.0    3.0  31.0  11.0
# 8276  14.0    39.939    116.483     0  2018.0    3.0  31.0  12.0
# 8277  12.0    39.939    116.483     0  2018.0    3.0  31.0  13.0
# 8278  14.0    39.939    116.483     0  2018.0    3.0  31.0  14.0
# 8279  13.0    39.939    116.483     0  2018.0    3.0  31.0  15.0
#
# [8280 rows x 15 columns]

# %%
temp_data['test'].value_counts()
# Out:
# 0    8071
# 1     209
# Name: test, dtype: int64

# %%
train_cv=temp_data.loc[temp_data['test']==0,:].copy()
test_cv=temp_data.loc[temp_data['test']==1,:].copy()

X_train=train_cv[col]
X_test=test_cv[col]
y=pd.concat([train_cv.test,test_cv.test])
data_cv = pd.concat([X_train, X_test])
data_cv.reset_index( inplace = True, drop = True )
y.reset_index( inplace = True, drop = True )
x=data_cv

# %%
clf = RF( n_estimators =100,n_jobs=-1,random_state=42)

# %%
predictions = np.zeros( y.shape )
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation as CV
cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)


for f, ( train_index, test_index ) in enumerate( cv ):
    
    print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
    x_train_adcv = x.iloc[train_index]
    x_test_adcv = x.iloc[test_index]
    y_train_adcv = y.iloc[train_index]
    y_test_adcv = y.iloc[test_index]
    
    clf.fit( x_train_adcv.values, y_train_adcv.values )
    
    p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
    auc = roc_auc_score( y_test_adcv, p )
    logloss=log_loss(y_test_adcv,p)
    print(auc)
    print ("# AUC: {:.2%}\n".format( auc )	)
    print ("# log_loss: {}\n".format( logloss )	)
    
    predictions[ test_index ] = p
# Out:
# # fold 1
# 0.7408356907119282
# # AUC: 74.08%
#
# # log_loss: 0.28621592943584767
#
# # fold 2
# 0.8605652917920577
# # AUC: 86.06%
#
# # log_loss: 0.15706107415077622
#
# # fold 3
# 0.8733109104856317
# # AUC: 87.33%
#
# # log_loss: 0.12111729320795388
#
# # fold 4
# 0.8797427273263704
# # AUC: 87.97%
#
# # log_loss: 0.12113680937070623
#
# # fold 5
# 0.9351802678940224
# # AUC: 93.52%
#
# # log_loss: 0.10391207289777998
#
# # fold 6
# 0.8890659113707441
# # AUC: 88.91%
#
# # log_loss: 0.14705315307768996
#
# # fold 7
# 0.8939045258747861
# # AUC: 89.39%
#
# # log_loss: 0.11519719882713661
#
# # fold 8
# 0.8164276863161621
# # AUC: 81.64%
#
# # log_loss: 0.20156051004093997
#
# # fold 9
# 0.873487932967487
# # AUC: 87.35%
#
# # log_loss: 0.15516623809441224
#
# # fold 10
# 0.8450433705080546
# # AUC: 84.50%
#
# # log_loss: 0.18840444843446666

# %%
plt.clf()
plt.figure(figsize=(20,10))
plt.title("Feature importances for dongsihuan_aq")
plt.xticks(range(X_train.shape[1]), col)
plt.bar(range(X_train.shape[1]), clf.feature_importances_,
       color="r", align="center")
#plt.plot(clf.feature_importances_)
plt.show()

# %% [markdown]
# Still high, then we did it by training batch on each station

# %% [markdown]
# #### If we use no time features !? what will happend

# %%
col=['PM10', 'NO2', 'CO', 'O3', 'SO2']
X_train=train_cv[col]
X_test=test_cv[col]
y=pd.concat([train_cv.test,test_cv.test])
data_cv = pd.concat([X_train, X_test])
data_cv.reset_index( inplace = True, drop = True )
y.reset_index( inplace = True, drop = True )
x=data_cv

# %%
clf = RF( n_estimators =100,n_jobs=-1,random_state=42)

# %%
predictions = np.zeros( y.shape )
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import log_loss
from sklearn.model_selection import StratifiedKFold
from sklearn import cross_validation as CV
cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)


for f, ( train_index, test_index ) in enumerate( cv ):
    
    print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
    x_train_adcv = x.iloc[train_index]
    x_test_adcv = x.iloc[test_index]
    y_train_adcv = y.iloc[train_index]
    y_test_adcv = y.iloc[test_index]
    
    clf.fit( x_train_adcv.values, y_train_adcv.values )
    
    p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
    auc = roc_auc_score( y_test_adcv, p )
    logloss=log_loss(y_test_adcv,p)
    print(auc)
    print ("# AUC: {:.2%}\n".format( auc )	)
    print ("# log_loss: {}\n".format( logloss )	)
    
    predictions[ test_index ] = p
# Out:
# # fold 1
# 0.6480139085337107
# # AUC: 64.80%
#
# # log_loss: 0.3426628423094844
#
# # fold 2
# 0.8126512067032514
# # AUC: 81.27%
#
# # log_loss: 0.20653568373213288
#
# # fold 3
# 0.718091697645601
# # AUC: 71.81%
#
# # log_loss: 0.2866960834853927
#
# # fold 4
# 0.7813772349088335
# # AUC: 78.14%
#
# # log_loss: 0.21446280470853843
#
# # fold 5
# 0.8569953384079778
# # AUC: 85.70%
#
# # log_loss: 0.12264263720196733
#
# # fold 6
# 0.7842686021124683
# # AUC: 78.43%
#
# # log_loss: 0.23717781904455942
#
# # fold 7
# 0.8490293267244939
# # AUC: 84.90%
#
# # log_loss: 0.15919759595340574
#
# # fold 8
# 0.7506933380539328
# # AUC: 75.07%
#
# # log_loss: 0.28359018508298645
#
# # fold 9
# 0.829881394937157
# # AUC: 82.99%
#
# # log_loss: 0.16380326951004265
#
# # fold 10
# 0.7924101610904586
# # AUC: 79.24%
#
# # log_loss: 0.2045800742591532

# %% [markdown]
# Thus we can see the time is the cause that make the distribution different, that is the missing value is not uniform distributed by time

# %%
plt.clf()
plt.figure(figsize=(20,10))
plt.title("Feature importances for dongsihuan_aq")
plt.xticks(range(X_train.shape[1]), col)
plt.bar(range(X_train.shape[1]), clf.feature_importances_,
       color="r", align="center")
#plt.plot(clf.feature_importances_)
plt.show()

# %%
col
# Out:
# ['PM10', 'NO2', 'CO', 'O3', 'SO2']

# %% [markdown]
# But PM1.0's distribution is not uniform

# %% [markdown]
# #### with time

# %%
col=['year', 'month', 'date', 'hour', 'PM10', 'NO2', 'CO', 'O3', 'SO2']
X_train=train_cv[col]
X_test=test_cv[col]
y=pd.concat([train_cv.test,test_cv.test])
data_cv = pd.concat([X_train, X_test])
data_cv.reset_index( inplace = True, drop = True )
y.reset_index( inplace = True, drop = True )
x=data_cv

# %%
import gc
#del temp_data
gc.collect()
for key in beji_aqi_summary.groupby(['stationId']).groups:
    clf = RF( n_estimators =100,n_jobs=-1,random_state=42)
    print(key)
    temp_data=beji_aqi_summary_copy.iloc[beji_aqi_summary_copy.groupby(['stationId']).groups[key]]
    print(temp_data['test'].value_counts())
    train_cv=temp_data.loc[temp_data['test']==0,:].copy()
    test_cv=temp_data.loc[temp_data['test']==1,:].copy()
    X_train=train_cv[col]
    X_test=test_cv[col]
    y=pd.concat([train_cv.test,test_cv.test])
    data_cv = pd.concat([X_train, X_test])
    data_cv.reset_index( inplace = True, drop = True )
    y.reset_index( inplace = True, drop = True )
    x=data_cv
    cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)
    accumulator_logloss=[]
    accumulator_AUC=[]
    predictions = np.zeros( y.shape )
    for f, ( train_index, test_index ) in enumerate( cv ):
    
        #print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
        x_train_adcv = x.iloc[train_index]
        x_test_adcv = x.iloc[test_index]
        y_train_adcv = y.iloc[train_index]
        y_test_adcv = y.iloc[test_index]
    
        clf.fit( x_train_adcv.values, y_train_adcv.values )
    
        p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
        auc = roc_auc_score( y_test_adcv, p )
        logloss=log_loss(y_test_adcv,p)
        accumulator_AUC.append( auc )
        accumulator_logloss.append(logloss)
        print ("# AUC: {:.2%}\n".format( auc )	)
        print ("# log_loss: {}\n".format( logloss )	)
        predictions[ test_index ] = p
        
    print ("** mean AUC: {:.2%}\n".format(np.mean(accumulator_AUC,axis=0)))
    print ("** mean log_loss: {}\n".format(np.mean(accumulator_logloss,axis=0)))
    print ("========================================")
    del accumulator_AUC, accumulator_logloss
    del temp_data
# Out:
# beibuxinqu_aq
# 0    9745
# 1      91
# Name: test, dtype: int64
# # AUC: 91.39%
#
# # log_loss: 0.0603271618355962
#
# # AUC: 91.42%
#
# # log_loss: 0.05263592332201199
#
# # AUC: 99.36%
#
# # log_loss: 0.017158314593272585
#
# # AUC: 84.75%
#
# # log_loss: 0.08922901841310302
#
# # AUC: 92.94%
#
# # log_loss: 0.04881992067642888
#
# # AUC: 85.19%
#
# # log_loss: 0.08610514732957214
#
# # AUC: 78.92%
#
# # log_loss: 0.12225733222486378
#
# # AUC: 73.07%
#
# # log_loss: 0.1554496264076108
#
# # AUC: 97.78%
#
# # log_loss: 0.022563485567874922
#
# # AUC: 86.63%
#
# # log_loss: 0.08489172507583229
#
# ** mean AUC: 88.15%
#
# ** mean log_loss: 0.07394376554461665
#
# ========================================
# aotizhongxin_aq
# 0    10093
# 1      111
# Name: test, dtype: int64
# # AUC: 88.73%
#
# # log_loss: 0.0911644914377208
#
# # AUC: 93.45%
#
# # log_loss: 0.05391014520294414
#
# # AUC: 91.85%
#
# # log_loss: 0.05755295804298377
#
# # AUC: 99.71%
#
# # log_loss: 0.01858448729001794
#
# # AUC: 99.98%
#
# # log_loss: 0.013074720622866983
#
# # AUC: 88.48%
#
# # log_loss: 0.08473660801618814
#
# # AUC: 99.91%
#
# # log_loss: 0.014876700444568914
#
# # AUC: 99.76%
#
# # log_loss: 0.0170252533362183
#
# # AUC: 93.01%
#
# # log_loss: 0.05874950100701076
#
# # AUC: 89.02%
#
# # log_loss: 0.08300512179315732
#
# ** mean AUC: 94.39%
#
# ** mean log_loss: 0.049267998719367705
#
# ========================================
# gucheng_aq
# 0    10041
# 1      140
# Name: test, dtype: int64
# # AUC: 95.14%
#
# # log_loss: 0.05364432933116954
#
# # AUC: 90.94%
#
# # log_loss: 0.08434822753018931
#
# # AUC: 94.72%
#
# # log_loss: 0.05743426646651237
#
# # AUC: 99.87%
#
# # log_loss: 0.017969509804532022
#
# # AUC: 95.27%
#
# # log_loss: 0.05421149253134217
#
# # AUC: 93.58%
#
# # log_loss: 0.061648628019211026
#
# # AUC: 99.18%
#
# # log_loss: 0.025803059867802285
#
# # AUC: 95.32%
#
# # log_loss: 0.052204306555539294
#
# # AUC: 86.75%
#
# # log_loss: 0.11989404232180391
#
# # AUC: 98.21%
#
# # log_loss: 0.02813136834373048
#
# ** mean AUC: 94.90%
#
# ** mean log_loss: 0.05552892307718325
#
# ========================================
# nansanhuan_aq
# 0    7899
# 1     438
# Name: test, dtype: int64
# # AUC: 95.93%
#
# # log_loss: 0.11565377648084488
#
# # AUC: 93.68%
#
# # log_loss: 0.13414524746315815
#
# # AUC: 97.36%
#
# # log_loss: 0.07827215598098544
#
# # AUC: 94.16%
#
# # log_loss: 0.16129595838930286
#
# # AUC: 97.61%
#
# # log_loss: 0.07107714612965235
#
# # AUC: 94.35%
#
# # log_loss: 0.12988996133697742
#
# # AUC: 96.06%
#
# # log_loss: 0.11036351543352137
#
# # AUC: 96.80%
#
# # log_loss: 0.10524958909002033
#
# # AUC: 96.97%
#
# # log_loss: 0.10628581908104456
#
# # AUC: 94.62%
#
# # log_loss: 0.14727975354539377
#
# ** mean AUC: 95.75%
#
# ** mean log_loss: 0.11595129229309012
#
# ========================================
# wanshouxigong_aq
# 0    9854
# 1     174
# Name: test, dtype: int64
# # AUC: 90.75%
#
# # log_loss: 0.09826340452771133
#
# # AUC: 98.15%
#
# # log_loss: 0.032842020284210335
#
# # AUC: 98.76%
#
# # log_loss: 0.028336454141201957
#
# # AUC: 97.33%
#
# # log_loss: 0.0339464003922325
#
# # AUC: 97.54%
#
# # log_loss: 0.035486016590706354
#
# # AUC: 90.96%
#
# # log_loss: 0.0994724649701907
#
# # AUC: 94.17%
#
# # log_loss: 0.0625471207783249
#
# # AUC: 95.14%
#
# # log_loss: 0.06486551194865203
#
# # AUC: 98.59%
#
# # log_loss: 0.03065269626223416
#
# # AUC: 93.84%
#
# # log_loss: 0.06339524425812113
#
# ** mean AUC: 95.52%
#
# ** mean log_loss: 0.05498073341535854
#
# ========================================
# yongdingmennei_aq
# 0    9797
# 1     135
# Name: test, dtype: int64
# # AUC: 92.68%
#
# # log_loss: 0.06385823193924144
#
# # AUC: 90.33%
#
# # log_loss: 0.08988917377409031
#
# # AUC: 96.83%
#
# # log_loss: 0.027980403781710808
#
# # AUC: 93.82%
#
# # log_loss: 0.05640485618882854
#
# # AUC: 94.46%
#
# # log_loss: 0.06004969955457773
#
# # AUC: 92.30%
#
# # log_loss: 0.061238464284529365
#
# # AUC: 92.18%
#
# # log_loss: 0.0637627515757242
#
# # AUC: 94.62%
#
# # log_loss: 0.05422743359164105
#
# # AUC: 83.71%
#
# # log_loss: 0.10680329181565708
#
# # AUC: 86.79%
#
# # log_loss: 0.09066299125641894
#
# ** mean AUC: 91.77%
#
# ** mean log_loss: 0.06748772977624194
#
# ========================================
# guanyuan_aq
# 0    9977
# 1     144
# Name: test, dtype: int64
# # AUC: 94.63%
#
# # log_loss: 0.056160596988896624
#
# # AUC: 94.52%
#
# # log_loss: 0.06228641981474945
#
# # AUC: 98.34%
#
# # log_loss: 0.02681404229072179
#
# # AUC: 84.46%
#
# # log_loss: 0.13091691540600073
#
# # AUC: 87.08%
#
# # log_loss: 0.11991684735209882
#
# # AUC: 95.09%
#
# # log_loss: 0.05793875966932032
#
# # AUC: 99.58%
#
# # log_loss: 0.021810524717414334
#
# # AUC: 94.73%
#
# # log_loss: 0.062026777047337514
#
# # AUC: 98.06%
#
# # log_loss: 0.02737973013632732
#
# # AUC: 94.85%
#
# # log_loss: 0.05655419541884368
#
# ** mean AUC: 94.13%
#
# ** mean log_loss: 0.062180480884171066
#
# ========================================
# qianmen_aq
# 0    9941
# 1      54
# Name: test, dtype: int64
# # AUC: 67.90%
#
# # log_loss: 0.11874289175770579
#
# # AUC: 96.66%
#
# # log_loss: 0.01926070042414406
#
# # AUC: 96.02%
#
# # log_loss: 0.022827841722161814
#
# # AUC: 89.10%
#
# # log_loss: 0.04844970045040036
#
# # AUC: 72.47%
#
# # log_loss: 0.08325811631488127
#
# # AUC: 83.95%
#
# # log_loss: 0.05202704849088575
#
# # AUC: 97.02%
#
# # log_loss: 0.016668100769280495
#
# # AUC: 64.76%
#
# # log_loss: 0.11244522190129293
#
# # AUC: 87.20%
#
# # log_loss: 0.04851133151337791
#
# # AUC: 99.26%
#
# # log_loss: 0.014182543088940023
#
# ** mean AUC: 85.43%
#
# ** mean log_loss: 0.05363734964330704
#
# ========================================
# yizhuang_aq
# 0    10034
# 1      136
# Name: test, dtype: int64
# # AUC: 99.78%
#
# # log_loss: 0.019200267982991376
#
# # AUC: 80.36%
#
# # log_loss: 0.1601587536346349
#
# # AUC: 99.81%
#
# # log_loss: 0.01825313296556881
#
# # AUC: 93.60%
#
# # log_loss: 0.06127580239494956
#
# # AUC: 95.34%
#
# # log_loss: 0.05430005805839693
#
# # AUC: 99.09%
#
# # log_loss: 0.02064468757418175
#
# # AUC: 89.49%
#
# # log_loss: 0.08982132330374984
#
# # AUC: 95.01%
#
# # log_loss: 0.05203685158175254
#
# # AUC: 88.83%
#
# # log_loss: 0.08757533475000787
#
# # AUC: 99.10%
#
# # log_loss: 0.018902766297890138
#
# ** mean AUC: 94.04%
#
# ** mean log_loss: 0.058216897854412364
#
# ========================================
# daxing_aq
# 0    9951
# 1     110
# Name: test, dtype: int64
# # AUC: 98.03%
#
# # log_loss: 0.02003362645983164
#
# # AUC: 98.87%
#
# # log_loss: 0.016040266012291
#
# # AUC: 83.82%
#
# # log_loss: 0.11549667385107484
#
# # AUC: 89.22%
#
# # log_loss: 0.07696802547201971
#
# # AUC: 92.30%
#
# # log_loss: 0.057501169683488645
#
# # AUC: 92.84%
#
# # log_loss: 0.0544346011694284
#
# # AUC: 97.17%
#
# # log_loss: 0.023470835366888158
#
# # AUC: 99.26%
#
# # log_loss: 0.0186910498134983
#
# # AUC: 93.76%
#
# # log_loss: 0.056210807176459925
#
# # AUC: 97.47%
#
# # log_loss: 0.019497569178021337
#
# ** mean AUC: 94.27%
#
# ** mean log_loss: 0.04583446241830019
#
# ========================================
# yungang_aq
# 0    9975
# 1     108
# Name: test, dtype: int64
# # AUC: 93.93%
#
# # log_loss: 0.05226946217270492
#
# # AUC: 88.84%
#
# # log_loss: 0.08346274913702356
#
# # AUC: 99.76%
#
# # log_loss: 0.016317145269237682
#
# # AUC: 91.95%
#
# # log_loss: 0.05603671458459589
#
# # AUC: 87.04%
#
# # log_loss: 0.09069069780756438
#
# # AUC: 93.58%
#
# # log_loss: 0.053806881600188726
#
# # AUC: 97.97%
#
# # log_loss: 0.020941339092205375
#
# # AUC: 87.77%
#
# # log_loss: 0.08991082731175827
#
# # AUC: 92.76%
#
# # log_loss: 0.0474926740561366
#
# # AUC: 99.94%
#
# # log_loss: 0.012232128911699683
#
# ** mean AUC: 93.35%
#
# ** mean log_loss: 0.052316061994311505
#
# ========================================
# dongsihuan_aq
# 0    8071
# 1     209
# Name: test, dtype: int64
# # AUC: 74.08%
#
# # log_loss: 0.28621592943584767
#
# # AUC: 86.06%
#
# # log_loss: 0.15706107415077622
#
# # AUC: 87.33%
#
# # log_loss: 0.12111729320795388
#
# # AUC: 87.97%
#
# # log_loss: 0.12113680937070623
#
# # AUC: 93.52%
#
# # log_loss: 0.10391207289777998
#
# # AUC: 88.91%
#
# # log_loss: 0.14705315307768996
#
# # AUC: 89.39%
#
# # log_loss: 0.11519719882713661
#
# # AUC: 81.64%
#
# # log_loss: 0.20156051004093997
#
# # AUC: 87.35%
#
# # log_loss: 0.15516623809441224
#
# # AUC: 84.50%
#
# # log_loss: 0.18840444843446666
#
# ** mean AUC: 86.08%
#
# ** mean log_loss: 0.15968247275377095
#
# ========================================
# shunyi_aq
# 0    10115
# 1       51
# Name: test, dtype: int64
# # AUC: 80.29%
#
# # log_loss: 0.08217603469575184
#
# # AUC: 87.78%
#
# # log_loss: 0.04581979634861865
#
# # AUC: 88.07%
#
# # log_loss: 0.04433807285512258
#
# # AUC: 98.02%
#
# # log_loss: 0.017433488264763965
#
# # AUC: 88.44%
#
# # log_loss: 0.04437450390024562
#
# # AUC: 77.48%
#
# # log_loss: 0.07714045721352816
#
# # AUC: 88.38%
#
# # log_loss: 0.046011086387374826
#
# # AUC: 99.18%
#
# # log_loss: 0.010486075023604954
#
# # AUC: 87.57%
#
# # log_loss: 0.04470597702397067
#
# # AUC: 88.52%
#
# # log_loss: 0.0422748295096328
#
# ** mean AUC: 88.37%
#
# ** mean log_loss: 0.04547603212226141
#
# ========================================
# zhiwuyuan_aq
# 0    6566
# 1     253
# Name: test, dtype: int64
# # AUC: 99.42%
#
# # log_loss: 0.041727565320548624
#
# # AUC: 97.77%
#
# # log_loss: 0.061733328818569765
#
# # AUC: 98.24%
#
# # log_loss: 0.05398621322256616
#
# # AUC: 98.28%
#
# # log_loss: 0.052529209447172466
#
# # AUC: 99.68%
#
# # log_loss: 0.03510636907156499
#
# # AUC: 99.14%
#
# # log_loss: 0.043617119651687825
#
# # AUC: 96.70%
#
# # log_loss: 0.0840357627163202
#
# # AUC: 98.03%
#
# # log_loss: 0.04543859565277259
#
# # AUC: 98.33%
#
# # log_loss: 0.04179582741277459
#
# # AUC: 94.75%
#
# # log_loss: 0.10385142402187521
#
# ** mean AUC: 98.03%
#
# ** mean log_loss: 0.05638214153358525
#
# ========================================
# wanliu_aq
# 0    10117
# 1       90
# Name: test, dtype: int64
# # AUC: 93.26%
#
# # log_loss: 0.048335814726216446
#
# # AUC: 86.81%
#
# # log_loss: 0.07741552498749354
#
# # AUC: 91.62%
#
# # log_loss: 0.05184453743554895
#
# # AUC: 84.82%
#
# # log_loss: 0.08306988920952697
#
# # AUC: 91.36%
#
# # log_loss: 0.05598060657194339
#
# # AUC: 99.68%
#
# # log_loss: 0.015829584156494516
#
# # AUC: 86.13%
#
# # log_loss: 0.08155118339960338
#
# # AUC: 91.96%
#
# # log_loss: 0.05404451132025384
#
# # AUC: 98.03%
#
# # log_loss: 0.018978519619756218
#
# # AUC: 97.69%
#
# # log_loss: 0.02194592383333635
#
# ** mean AUC: 92.13%
#
# ** mean log_loss: 0.05089960952601737
#
# ========================================
# nongzhanguan_aq
# 0    9925
# 1     102
# Name: test, dtype: int64
# # AUC: 93.83%
#
# # log_loss: 0.05428017755335572
#
# # AUC: 90.85%
#
# # log_loss: 0.0631384462757289
#
# # AUC: 98.29%
#
# # log_loss: 0.024016664697099295
#
# # AUC: 99.51%
#
# # log_loss: 0.01856404582050923
#
# # AUC: 98.83%
#
# # log_loss: 0.020455578989968862
#
# # AUC: 99.80%
#
# # log_loss: 0.01650628463373675
#
# # AUC: 92.08%
#
# # log_loss: 0.06284265248323564
#
# # AUC: 92.45%
#
# # log_loss: 0.0567019396176087
#
# # AUC: 97.77%
#
# # log_loss: 0.02523307151037607
#
# # AUC: 98.23%
#
# # log_loss: 0.025583780834067763
#
# ** mean AUC: 96.16%
#
# ** mean log_loss: 0.036732264241568696
#
# ========================================
# mentougou_aq
# 0    10006
# 1       99
# Name: test, dtype: int64
# # AUC: 99.95%
#
# # log_loss: 0.013282898664404848
#
# # AUC: 93.91%
#
# # log_loss: 0.04539883091353307
#
# # AUC: 98.98%
#
# # log_loss: 0.020283657961900264
#
# # AUC: 93.25%
#
# # log_loss: 0.050090780543601963
#
# # AUC: 99.10%
#
# # log_loss: 0.022987938005320792
#
# # AUC: 93.74%
#
# # log_loss: 0.048789554991265485
#
# # AUC: 88.10%
#
# # log_loss: 0.08148636120237243
#
# # AUC: 93.24%
#
# # log_loss: 0.04912081419189787
#
# # AUC: 98.86%
#
# # log_loss: 0.025139652289635692
#
# # AUC: 99.67%
#
# # log_loss: 0.014298149474634736
#
# ** mean AUC: 95.88%
#
# ** mean log_loss: 0.037087863823856725
#
# ========================================
# pinggu_aq
# 0    9877
# 1     137
# Name: test, dtype: int64
# # AUC: 90.42%
#
# # log_loss: 0.09114704915950256
#
# # AUC: 90.12%
#
# # log_loss: 0.08915275165209774
#
# # AUC: 98.04%
#
# # log_loss: 0.027244328442145544
#
# # AUC: 76.79%
#
# # log_loss: 0.19053859290805075
#
# # AUC: 94.40%
#
# # log_loss: 0.0574599927255247
#
# # AUC: 95.00%
#
# # log_loss: 0.038199653538733246
#
# # AUC: 94.53%
#
# # log_loss: 0.05905366316442689
#
# # AUC: 88.57%
#
# # log_loss: 0.0896701116322002
#
# # AUC: 97.52%
#
# # log_loss: 0.025641332093402143
#
# # AUC: 91.84%
#
# # log_loss: 0.06296923711774918
#
# ** mean AUC: 91.72%
#
# ** mean log_loss: 0.0731076712433833
#
# ========================================
# liulihe_aq
# 0    7670
# 1     184
# Name: test, dtype: int64
# # AUC: 80.48%
#
# # log_loss: 0.19103618270116374
#
# # AUC: 87.26%
#
# # log_loss: 0.146162480144208
#
# # AUC: 80.93%
#
# # log_loss: 0.1920236983646055
#
# # AUC: 89.96%
#
# # log_loss: 0.10722660672413045
#
# # AUC: 86.08%
#
# # log_loss: 0.14387942525118258
#
# # AUC: 83.70%
#
# # log_loss: 0.18243793416067777
#
# # AUC: 80.87%
#
# # log_loss: 0.2243893050553591
#
# # AUC: 87.49%
#
# # log_loss: 0.1117606185467299
#
# # AUC: 88.50%
#
# # log_loss: 0.140103174107769
#
# # AUC: 91.32%
#
# # log_loss: 0.10782091168066556
#
# ** mean AUC: 85.66%
#
# ** mean log_loss: 0.15468403367364916
#
# ========================================
# huairou_aq
# 0    9876
# 1     117
# Name: test, dtype: int64
# # AUC: 94.83%
#
# # log_loss: 0.051438997205887016
#
# # AUC: 93.95%
#
# # log_loss: 0.053661298833042326
#
# # AUC: 98.48%
#
# # log_loss: 0.02105541109629382
#
# # AUC: 94.20%
#
# # log_loss: 0.05406235488895247
#
# # AUC: 89.79%
#
# # log_loss: 0.08616302587522481
#
# # AUC: 94.67%
#
# # log_loss: 0.05314456079654432
#
# # AUC: 89.75%
#
# # log_loss: 0.08672270933870102
#
# # AUC: 99.23%
#
# # log_loss: 0.021328010277823464
#
# # AUC: 98.27%
#
# # log_loss: 0.026858733221632045
#
# # AUC: 93.87%
#
# # log_loss: 0.05203606173685481
#
# ** mean AUC: 94.70%
#
# ** mean log_loss: 0.050647116327095607
#
# ========================================
# miyunshuiku_aq
# 0    9493
# 1     193
# Name: test, dtype: int64
# # AUC: 83.57%
#
# # log_loss: 0.2049522643552578
#
# # AUC: 98.25%
#
# # log_loss: 0.033343996127403255
#
# # AUC: 95.11%
#
# # log_loss: 0.0707034949682983
#
# # AUC: 98.20%
#
# # log_loss: 0.034584201851087897
#
# # AUC: 91.36%
#
# # log_loss: 0.1038205276536383
#
# # AUC: 91.41%
#
# # log_loss: 0.10898845842188416
#
# # AUC: 95.80%
#
# # log_loss: 0.061881208845666766
#
# # AUC: 98.84%
#
# # log_loss: 0.0342009103819671
#
# # AUC: 96.80%
#
# # log_loss: 0.038936284056657396
#
# # AUC: 92.89%
#
# # log_loss: 0.09465989819634653
#
# ** mean AUC: 94.22%
#
# ** mean log_loss: 0.07860712448582076
#
# ========================================
# xizhimenbei_aq
# 0    9809
# 1      77
# Name: test, dtype: int64
# # AUC: 91.79%
#
# # log_loss: 0.053765377766405394
#
# # AUC: 91.97%
#
# # log_loss: 0.0529879952645861
#
# # AUC: 83.45%
#
# # log_loss: 0.08607180184288744
#
# # AUC: 92.12%
#
# # log_loss: 0.050996184390631145
#
# # AUC: 90.78%
#
# # log_loss: 0.05529690960635295
#
# # AUC: 99.90%
#
# # log_loss: 0.01704873847254014
#
# # AUC: 87.50%
#
# # log_loss: 0.05818369459668857
#
# # AUC: 90.73%
#
# # log_loss: 0.049935995039406135
#
# # AUC: 83.94%
#
# # log_loss: 0.06276279223547827
#
# # AUC: 83.46%
#
# # log_loss: 0.06370003823129619
#
# ** mean AUC: 89.57%
#
# ** mean log_loss: 0.05507495274462724
#
# ========================================
# yanqin_aq
# 0    9932
# 1     192
# Name: test, dtype: int64
# # AUC: 93.32%
#
# # log_loss: 0.06673481811456415
#
# # AUC: 91.63%
#
# # log_loss: 0.09974199817425607
#
# # AUC: 92.29%
#
# # log_loss: 0.10020768838246828
#
# # AUC: 99.03%
#
# # log_loss: 0.03137845218135399
#
# # AUC: 98.25%
#
# # log_loss: 0.029312255665303728
#
# # AUC: 85.94%
#
# # log_loss: 0.14106145992420152
#
# # AUC: 91.22%
#
# # log_loss: 0.10070608360183457
#
# # AUC: 94.57%
#
# # log_loss: 0.06971331981353747
#
# # AUC: 94.37%
#
# # log_loss: 0.06744573215194716
#
# # AUC: 97.61%
#
# # log_loss: 0.03170634179949681
#
# ** mean AUC: 93.82%
#
# ** mean log_loss: 0.07380081498089638
#
# ========================================
# dongsi_aq
# 0    9962
# 1      74
# Name: test, dtype: int64
# # AUC: 98.48%
#
# # log_loss: 0.01703275276444287
#
# # AUC: 95.67%
#
# # log_loss: 0.024872575218346276
#
# # AUC: 90.79%
#
# # log_loss: 0.051993934778484914
#
# # AUC: 97.77%
#
# # log_loss: 0.024175418866795303
#
# # AUC: 99.50%
#
# # log_loss: 0.013914916015750461
#
# # AUC: 90.97%
#
# # log_loss: 0.05195616481536955
#
# # AUC: 83.33%
#
# # log_loss: 0.08117347025165807
#
# # AUC: 71.12%
#
# # log_loss: 0.12688678828046027
#
# # AUC: 99.56%
#
# # log_loss: 0.015164020452041963
#
# # AUC: 96.93%
#
# # log_loss: 0.02293130326451912
#
# ** mean AUC: 92.41%
#
# ** mean log_loss: 0.04301013447078687
#
# ========================================
# fengtaihuayuan_aq
# 0    9967
# 1     197
# Name: test, dtype: int64
# # AUC: 92.37%
#
# # log_loss: 0.08773182145989854
#
# # AUC: 89.71%
#
# # log_loss: 0.12061529813702243
#
# # AUC: 89.81%
#
# # log_loss: 0.12829213168124518
#
# # AUC: 88.27%
#
# # log_loss: 0.13255190096629
#
# # AUC: 92.07%
#
# # log_loss: 0.09907894597715254
#
# # AUC: 99.20%
#
# # log_loss: 0.02764636861323978
#
# # AUC: 97.98%
#
# # log_loss: 0.03125460726151902
#
# # AUC: 95.05%
#
# # log_loss: 0.06285151311658004
#
# # AUC: 92.45%
#
# # log_loss: 0.09096118883920587
#
# # AUC: 89.99%
#
# # log_loss: 0.09940464786128915
#
# ** mean AUC: 92.69%
#
# ** mean log_loss: 0.08803884239134425
#
# ========================================
# tongzhou_aq
# 0    8988
# 1     152
# Name: test, dtype: int64
# # AUC: 97.69%
#
# # log_loss: 0.04155380727866926
#
# # AUC: 93.71%
#
# # log_loss: 0.06930879722404179
#
# # AUC: 86.82%
#
# # log_loss: 0.11475085375198577
#
# # AUC: 83.39%
#
# # log_loss: 0.14594412958663458
#
# # AUC: 94.01%
#
# # log_loss: 0.07058944333911181
#
# # AUC: 89.28%
#
# # log_loss: 0.1050772765477306
#
# # AUC: 86.80%
#
# # log_loss: 0.11149310881606118
#
# # AUC: 86.82%
#
# # log_loss: 0.11067834192979355
#
# # AUC: 96.96%
#
# # log_loss: 0.03149163929058121
#
# # AUC: 97.48%
#
# # log_loss: 0.03388750395318129
#
# ** mean AUC: 91.30%
#
# ** mean log_loss: 0.0834774901717791
#
# ========================================
# donggaocun_aq
# 0    9623
# 1     114
# Name: test, dtype: int64
# # AUC: 93.49%
#
# # log_loss: 0.06070587800603498
#
# # AUC: 93.32%
#
# # log_loss: 0.05579611927008149
#
# # AUC: 92.53%
#
# # log_loss: 0.06219583403708552
#
# # AUC: 93.26%
#
# # log_loss: 0.05577192754444492
#
# # AUC: 91.00%
#
# # log_loss: 0.06229405563229671
#
# # AUC: 82.46%
#
# # log_loss: 0.1255265801025476
#
# # AUC: 99.57%
#
# # log_loss: 0.020842195330078212
#
# # AUC: 96.88%
#
# # log_loss: 0.028902161338820086
#
# # AUC: 86.89%
#
# # log_loss: 0.0954198587602722
#
# # AUC: 97.64%
#
# # log_loss: 0.02703986250016223
#
# ** mean AUC: 92.70%
#
# ** mean log_loss: 0.059449447252182396
#
# ========================================
# miyun_aq
# 0    10034
# 1       90
# Name: test, dtype: int64
# # AUC: 91.64%
#
# # log_loss: 0.05200120998572619
#
# # AUC: 80.23%
#
# # log_loss: 0.1129974849562098
#
# # AUC: 97.71%
#
# # log_loss: 0.024357894476099668
#
# # AUC: 99.21%
#
# # log_loss: 0.020525644660759228
#
# # AUC: 93.53%
#
# # log_loss: 0.04593081556613079
#
# # AUC: 85.98%
#
# # log_loss: 0.08340374281431988
#
# # AUC: 86.11%
#
# # log_loss: 0.08537433154424164
#
# # AUC: 85.66%
#
# # log_loss: 0.08836313737083074
#
# # AUC: 92.77%
#
# # log_loss: 0.05179637913190918
#
# # AUC: 92.66%
#
# # log_loss: 0.04980351869463149
#
# ** mean AUC: 90.55%
#
# ** mean log_loss: 0.061455415920085854
#
# ========================================
# dingling_aq
# 0    10201
# 1       60
# Name: test, dtype: int64
# # AUC: 89.82%
#
# # log_loss: 0.045643595681726656
#
# # AUC: 97.83%
#
# # log_loss: 0.01660459606278423
#
# # AUC: 90.15%
#
# # log_loss: 0.042455003254303354
#
# # AUC: 86.99%
#
# # log_loss: 0.05092292611185575
#
# # AUC: 78.32%
#
# # log_loss: 0.08494975855222255
#
# # AUC: 99.38%
#
# # log_loss: 0.012166452387942102
#
# # AUC: 99.02%
#
# # log_loss: 0.015215911696766617
#
# # AUC: 70.07%
#
# # log_loss: 0.11367321834042755
#
# # AUC: 97.31%
#
# # log_loss: 0.0167083344711182
#
# # AUC: 97.86%
#
# # log_loss: 0.01359791970847941
#
# ** mean AUC: 90.68%
#
# ** mean log_loss: 0.04119377162676264
#
# ========================================
# yufa_aq
# 0    9596
# 1     199
# Name: test, dtype: int64
# # AUC: 85.76%
#
# # log_loss: 0.14959128423706905
#
# # AUC: 92.61%
#
# # log_loss: 0.07921552486333042
#
# # AUC: 90.62%
#
# # log_loss: 0.08399180768021941
#
# # AUC: 91.83%
#
# # log_loss: 0.10896548198195709
#
# # AUC: 93.05%
#
# # log_loss: 0.08051939328110566
#
# # AUC: 96.29%
#
# # log_loss: 0.045984140866815036
#
# # AUC: 82.26%
#
# # log_loss: 0.15689305847011684
#
# # AUC: 83.21%
#
# # log_loss: 0.15579148879599167
#
# # AUC: 93.67%
#
# # log_loss: 0.07350113686013765
#
# # AUC: 84.19%
#
# # log_loss: 0.15103614342042113
#
# ** mean AUC: 89.35%
#
# ** mean log_loss: 0.10854894604571638
#
# ========================================
# fangshan_aq
# 0    10019
# 1      119
# Name: test, dtype: int64
# # AUC: 94.26%
#
# # log_loss: 0.056348921927779794
#
# # AUC: 98.09%
#
# # log_loss: 0.02728352743279774
#
# # AUC: 90.93%
#
# # log_loss: 0.06469132131399168
#
# # AUC: 83.10%
#
# # log_loss: 0.12329197372723051
#
# # AUC: 94.17%
#
# # log_loss: 0.036650227528278075
#
# # AUC: 86.71%
#
# # log_loss: 0.09459160618378762
#
# # AUC: 94.84%
#
# # log_loss: 0.031373324049150095
#
# # AUC: 98.66%
#
# # log_loss: 0.02582014194933164
#
# # AUC: 90.88%
#
# # log_loss: 0.0672860847525058
#
# # AUC: 83.53%
#
# # log_loss: 0.09405783758801119
#
# ** mean AUC: 91.52%
#
# ** mean log_loss: 0.06213949664528642
#
# ========================================
# tiantan_aq
# 0    9949
# 1     108
# Name: test, dtype: int64
# # AUC: 98.87%
#
# # log_loss: 0.02199866978908328
#
# # AUC: 99.88%
#
# # log_loss: 0.015437110492385912
#
# # AUC: 92.49%
#
# # log_loss: 0.053836498516446354
#
# # AUC: 99.81%
#
# # log_loss: 0.01677172156505118
#
# # AUC: 92.54%
#
# # log_loss: 0.0571112451354673
#
# # AUC: 90.92%
#
# # log_loss: 0.06154477279480627
#
# # AUC: 99.06%
#
# # log_loss: 0.022928283958661304
#
# # AUC: 96.89%
#
# # log_loss: 0.026472056035789403
#
# # AUC: 90.55%
#
# # log_loss: 0.06132770314768248
#
# # AUC: 80.75%
#
# # log_loss: 0.11673028455975105
#
# ** mean AUC: 94.18%
#
# ** mean log_loss: 0.04541583459951245
#
# ========================================
# yongledian_aq
# 0    9869
# 1      77
# Name: test, dtype: int64
# # AUC: 75.92%
#
# # log_loss: 0.11928914807830264
#
# # AUC: 77.83%
#
# # log_loss: 0.09819343805249167
#
# # AUC: 68.10%
#
# # log_loss: 0.14906381921163026
#
# # AUC: 79.20%
#
# # log_loss: 0.09036913785109138
#
# # AUC: 67.22%
#
# # log_loss: 0.15604117898472525
#
# # AUC: 80.88%
#
# # log_loss: 0.09196548061295555
#
# # AUC: 95.92%
#
# # log_loss: 0.028674396648352796
#
# # AUC: 81.02%
#
# # log_loss: 0.08870614423514192
#
# # AUC: 71.78%
#
# # log_loss: 0.12101630002152795
#
# # AUC: 81.53%
#
# # log_loss: 0.08217295864042859
#
# ** mean AUC: 77.94%
#
# ** mean log_loss: 0.1025492002336648
#
# ========================================
# pingchang_aq
# 0    10005
# 1      118
# Name: test, dtype: int64
# # AUC: 99.92%
#
# # log_loss: 0.01672808793370621
#
# # AUC: 94.36%
#
# # log_loss: 0.05400852744388316
#
# # AUC: 95.09%
#
# # log_loss: 0.0490062917885043
#
# # AUC: 98.31%
#
# # log_loss: 0.02055133441606247
#
# # AUC: 93.53%
#
# # log_loss: 0.056653679702244754
#
# # AUC: 93.79%
#
# # log_loss: 0.054427447555643944
#
# # AUC: 94.84%
#
# # log_loss: 0.05055572523359825
#
# # AUC: 94.24%
#
# # log_loss: 0.05376608363042447
#
# # AUC: 93.73%
#
# # log_loss: 0.05305621383004628
#
# # AUC: 98.25%
#
# # log_loss: 0.03227104370968008
#
# ** mean AUC: 95.60%
#
# ** mean log_loss: 0.04410244352437939
#
# ========================================
# badaling_aq
# 0    9994
# 1     171
# Name: test, dtype: int64
# # AUC: 92.83%
#
# # log_loss: 0.08840160736554234
#
# # AUC: 94.52%
#
# # log_loss: 0.05867873211565103
#
# # AUC: 97.54%
#
# # log_loss: 0.02820755149278567
#
# # AUC: 91.86%
#
# # log_loss: 0.08874207623943328
#
# # AUC: 91.60%
#
# # log_loss: 0.09268715105375094
#
# # AUC: 87.95%
#
# # log_loss: 0.12681600766483153
#
# # AUC: 89.00%
#
# # log_loss: 0.1194533487426978
#
# # AUC: 84.77%
#
# # log_loss: 0.1579036377482527
#
# # AUC: 98.38%
#
# # log_loss: 0.025955087078992526
#
# # AUC: 92.65%
#
# # log_loss: 0.08485052273352897
#
# ** mean AUC: 92.11%
#
# ** mean log_loss: 0.08716957222354668
#
# ========================================

# %% [markdown]
# The result is really bad, it can be easily detected, it's hard for the missing value imputation which implement by the surpervised learning model.

# %% [markdown]
# #### without time

# %%
col=['PM10', 'NO2', 'CO', 'O3', 'SO2']
X_train=train_cv[col]
X_test=test_cv[col]
y=pd.concat([train_cv.test,test_cv.test])
data_cv = pd.concat([X_train, X_test])
data_cv.reset_index( inplace = True, drop = True )
y.reset_index( inplace = True, drop = True )
x=data_cv

# %%
import gc
#del temp_data
gc.collect()
for key in beji_aqi_summary.groupby(['stationId']).groups:
    clf = RF( n_estimators =100,n_jobs=-1,random_state=42)
    print(key)
    temp_data=beji_aqi_summary_copy.iloc[beji_aqi_summary_copy.groupby(['stationId']).groups[key]]
    print(temp_data['test'].value_counts())
    train_cv=temp_data.loc[temp_data['test']==0,:].copy()
    test_cv=temp_data.loc[temp_data['test']==1,:].copy()
    X_train=train_cv[col]
    X_test=test_cv[col]
    y=pd.concat([train_cv.test,test_cv.test])
    data_cv = pd.concat([X_train, X_test])
    data_cv.reset_index( inplace = True, drop = True )
    y.reset_index( inplace = True, drop = True )
    x=data_cv
    cv = CV.StratifiedKFold( y, n_folds = 10, shuffle = True, random_state = 42)
    accumulator_logloss=[]
    accumulator_AUC=[]
    predictions = np.zeros( y.shape )
    for f, ( train_index, test_index ) in enumerate( cv ):
    
        #print ("# fold {}".format( f + 1))
    #print("TRAIN:", train_index, "TEST:", test_index)
        x_train_adcv = x.iloc[train_index]
        x_test_adcv = x.iloc[test_index]
        y_train_adcv = y.iloc[train_index]
        y_test_adcv = y.iloc[test_index]
    
        clf.fit( x_train_adcv.values, y_train_adcv.values )
    
        p = clf.predict_proba( x_test_adcv.values  )[:,1] # the probability of "1" class
    
        auc = roc_auc_score( y_test_adcv, p )
        logloss=log_loss(y_test_adcv,p)
        accumulator_AUC.append( auc )
        accumulator_logloss.append(logloss)
        print ("# AUC: {:.2%}\n".format( auc )	)
        print ("# log_loss: {}\n".format( logloss )	)
        predictions[ test_index ] = p
        
    print ("** mean AUC: {:.2%}\n".format(np.mean(accumulator_AUC,axis=0)))
    print ("** mean log_loss: {}\n".format(np.mean(accumulator_logloss,axis=0)))
    print ("========================================")
    del accumulator_AUC, accumulator_logloss
    del temp_data
# Out:
# beibuxinqu_aq
# 0    9745
# 1      91
# Name: test, dtype: int64
# # AUC: 80.57%
#
# # log_loss: 0.12372880393833047
#
# # AUC: 80.64%
#
# # log_loss: 0.11527134579903853
#
# # AUC: 86.52%
#
# # log_loss: 0.08541261086954308
#
# # AUC: 67.72%
#
# # log_loss: 0.1855354522603813
#
# # AUC: 91.62%
#
# # log_loss: 0.055267120738023624
#
# # AUC: 84.55%
#
# # log_loss: 0.08756379531238472
#
# # AUC: 67.23%
#
# # log_loss: 0.18587716073941518
#
# # AUC: 60.89%
#
# # log_loss: 0.22059477022954807
#
# # AUC: 86.33%
#
# # log_loss: 0.0860220018362606
#
# # AUC: 79.38%
#
# # log_loss: 0.12073628272438357
#
# ** mean AUC: 78.55%
#
# ** mean log_loss: 0.12660093444473092
#
# ========================================
# aotizhongxin_aq
# 0    10093
# 1      111
# Name: test, dtype: int64
# # AUC: 60.66%
#
# # log_loss: 0.2812378055944679
#
# # AUC: 91.38%
#
# # log_loss: 0.06574216893888889
#
# # AUC: 82.28%
#
# # log_loss: 0.12373844495940639
#
# # AUC: 91.42%
#
# # log_loss: 0.06758726459699935
#
# # AUC: 88.95%
#
# # log_loss: 0.08329137145425226
#
# # AUC: 83.15%
#
# # log_loss: 0.1215426557953874
#
# # AUC: 92.37%
#
# # log_loss: 0.061415706545336735
#
# # AUC: 87.71%
#
# # log_loss: 0.09154823610078142
#
# # AUC: 79.62%
#
# # log_loss: 0.1323215109232975
#
# # AUC: 81.53%
#
# # log_loss: 0.1259798399257227
#
# ** mean AUC: 83.91%
#
# ** mean log_loss: 0.11544050048345404
#
# ========================================
# gucheng_aq
# 0    10041
# 1      140
# Name: test, dtype: int64
# # AUC: 90.09%
#
# # log_loss: 0.09251764133224549
#
# # AUC: 90.35%
#
# # log_loss: 0.09335029962854675
#
# # AUC: 88.53%
#
# # log_loss: 0.09811250700269752
#
# # AUC: 94.37%
#
# # log_loss: 0.05987803136370648
#
# # AUC: 89.68%
#
# # log_loss: 0.09278269564224781
#
# # AUC: 72.31%
#
# # log_loss: 0.22334847473715608
#
# # AUC: 92.92%
#
# # log_loss: 0.06903544361799194
#
# # AUC: 90.53%
#
# # log_loss: 0.07216997346262415
#
# # AUC: 80.77%
#
# # log_loss: 0.1605994549451206
#
# # AUC: 88.40%
#
# # log_loss: 0.0972385116455898
#
# ** mean AUC: 87.80%
#
# ** mean log_loss: 0.10590330333779266
#
# ========================================
# nansanhuan_aq
# 0    7899
# 1     438
# Name: test, dtype: int64
# # AUC: 91.30%
#
# # log_loss: 0.19303338521312072
#
# # AUC: 87.91%
#
# # log_loss: 0.21506956552701798
#
# # AUC: 93.21%
#
# # log_loss: 0.14939453340156425
#
# # AUC: 87.64%
#
# # log_loss: 0.2499857631692033
#
# # AUC: 93.87%
#
# # log_loss: 0.11370678129377466
#
# # AUC: 89.46%
#
# # log_loss: 0.1775336213735591
#
# # AUC: 89.66%
#
# # log_loss: 0.20406548064227062
#
# # AUC: 91.72%
#
# # log_loss: 0.19224994379476787
#
# # AUC: 91.06%
#
# # log_loss: 0.159944206766681
#
# # AUC: 90.67%
#
# # log_loss: 0.16029202769433495
#
# ** mean AUC: 90.65%
#
# ** mean log_loss: 0.18152753088762946
#
# ========================================
# wanshouxigong_aq
# 0    9854
# 1     174
# Name: test, dtype: int64
# # AUC: 84.54%
#
# # log_loss: 0.15047068819838297
#
# # AUC: 87.75%
#
# # log_loss: 0.11938879869738393
#
# # AUC: 86.63%
#
# # log_loss: 0.14494399709621805
#
# # AUC: 92.10%
#
# # log_loss: 0.08277856706093585
#
# # AUC: 84.26%
#
# # log_loss: 0.14507017791457139
#
# # AUC: 84.32%
#
# # log_loss: 0.15017368663935232
#
# # AUC: 84.07%
#
# # log_loss: 0.1501350841580053
#
# # AUC: 80.17%
#
# # log_loss: 0.18454319020013446
#
# # AUC: 88.16%
#
# # log_loss: 0.1140546932437469
#
# # AUC: 90.12%
#
# # log_loss: 0.10967141516025335
#
# ** mean AUC: 86.21%
#
# ** mean log_loss: 0.13512302983689845
#
# ========================================
# yongdingmennei_aq
# 0    9797
# 1     135
# Name: test, dtype: int64
# # AUC: 87.88%
#
# # log_loss: 0.10682060284323239
#
# # AUC: 82.36%
#
# # log_loss: 0.14391318320190272
#
# # AUC: 87.18%
#
# # log_loss: 0.10802153925187236
#
# # AUC: 84.34%
#
# # log_loss: 0.13545038324395703
#
# # AUC: 88.02%
#
# # log_loss: 0.10695547818868119
#
# # AUC: 89.07%
#
# # log_loss: 0.09936397261705593
#
# # AUC: 73.49%
#
# # log_loss: 0.2026930903055383
#
# # AUC: 79.46%
#
# # log_loss: 0.14121873981618796
#
# # AUC: 74.89%
#
# # log_loss: 0.178467423951761
#
# # AUC: 82.91%
#
# # log_loss: 0.13790398330189074
#
# ** mean AUC: 82.96%
#
# ** mean log_loss: 0.13608083967220794
#
# ========================================
# guanyuan_aq
# 0    9977
# 1     144
# Name: test, dtype: int64
# # AUC: 92.66%
#
# # log_loss: 0.07372576962532992
#
# # AUC: 81.16%
#
# # log_loss: 0.14877993870614564
#
# # AUC: 88.24%
#
# # log_loss: 0.10598943894413713
#
# # AUC: 71.74%
#
# # log_loss: 0.23398718959288028
#
# # AUC: 85.19%
#
# # log_loss: 0.13076405507199443
#
# # AUC: 85.59%
#
# # log_loss: 0.11042418333755823
#
# # AUC: 89.85%
#
# # log_loss: 0.09282525813472137
#
# # AUC: 85.24%
#
# # log_loss: 0.12912224683222706
#
# # AUC: 74.67%
#
# # log_loss: 0.1997777594908733
#
# # AUC: 85.69%
#
# # log_loss: 0.10388750651175235
#
# ** mean AUC: 84.00%
#
# ** mean log_loss: 0.132928334624762
#
# ========================================
# qianmen_aq
# 0    9941
# 1      54
# Name: test, dtype: int64
# # AUC: 60.63%
#
# # log_loss: 0.15026924147169451
#
# # AUC: 68.96%
#
# # log_loss: 0.1169051358931668
#
# # AUC: 75.75%
#
# # log_loss: 0.08908265929909469
#
# # AUC: 78.19%
#
# # log_loss: 0.08474110292252693
#
# # AUC: 73.03%
#
# # log_loss: 0.08617420523394832
#
# # AUC: 42.61%
#
# # log_loss: 0.17733143426344225
#
# # AUC: 65.23%
#
# # log_loss: 0.1126748137054144
#
# # AUC: 63.35%
#
# # log_loss: 0.11542362002113965
#
# # AUC: 73.40%
#
# # log_loss: 0.08401172615233064
#
# # AUC: 86.96%
#
# # log_loss: 0.050827531437696506
#
# ** mean AUC: 68.81%
#
# ** mean log_loss: 0.10674414704004546
#
# ========================================
# yizhuang_aq
# 0    10034
# 1      136
# Name: test, dtype: int64
# # AUC: 90.81%
#
# # log_loss: 0.07447490887182903
#
# # AUC: 71.62%
#
# # log_loss: 0.23403048285125005
#
# # AUC: 89.18%
#
# # log_loss: 0.0996218397984353
#
# # AUC: 76.10%
#
# # log_loss: 0.1979666276973328
#
# # AUC: 92.90%
#
# # log_loss: 0.07116898164674475
#
# # AUC: 96.92%
#
# # log_loss: 0.035643724216971526
#
# # AUC: 79.18%
#
# # log_loss: 0.1625491126119498
#
# # AUC: 89.14%
#
# # log_loss: 0.09470527280566512
#
# # AUC: 83.76%
#
# # log_loss: 0.1310137849345155
#
# # AUC: 98.12%
#
# # log_loss: 0.03152322895867158
#
# ** mean AUC: 86.77%
#
# ** mean log_loss: 0.11326979643933655
#
# ========================================
# daxing_aq
# 0    9951
# 1     110
# Name: test, dtype: int64
# # AUC: 94.04%
#
# # log_loss: 0.05208143171741298
#
# # AUC: 94.29%
#
# # log_loss: 0.04962812729260021
#
# # AUC: 81.24%
#
# # log_loss: 0.12680522326748467
#
# # AUC: 89.28%
#
# # log_loss: 0.07738789250921022
#
# # AUC: 78.23%
#
# # log_loss: 0.15141947704094727
#
# # AUC: 77.53%
#
# # log_loss: 0.15470589897618886
#
# # AUC: 93.43%
#
# # log_loss: 0.05431581738983868
#
# # AUC: 85.55%
#
# # log_loss: 0.09276985012233094
#
# # AUC: 87.58%
#
# # log_loss: 0.09143209946088712
#
# # AUC: 78.15%
#
# # log_loss: 0.15305176092677536
#
# ** mean AUC: 85.93%
#
# ** mean log_loss: 0.10035975787036763
#
# ========================================
# yungang_aq
# 0    9975
# 1     108
# Name: test, dtype: int64
# # AUC: 90.24%
#
# # log_loss: 0.05968277576352871
#
# # AUC: 78.38%
#
# # log_loss: 0.1505750942568463
#
# # AUC: 88.71%
#
# # log_loss: 0.08254401514628135
#
# # AUC: 82.01%
#
# # log_loss: 0.12515978598277872
#
# # AUC: 82.80%
#
# # log_loss: 0.122667692354705
#
# # AUC: 82.59%
#
# # log_loss: 0.11966988550894175
#
# # AUC: 92.00%
#
# # log_loss: 0.055444268423209
#
# # AUC: 80.81%
#
# # log_loss: 0.12736909973234317
#
# # AUC: 92.51%
#
# # log_loss: 0.052657503981630514
#
# # AUC: 99.70%
#
# # log_loss: 0.016034934538400884
#
# ** mean AUC: 86.98%
#
# ** mean log_loss: 0.09118050556886653
#
# ========================================
# dongsihuan_aq
# 0    8071
# 1     209
# Name: test, dtype: int64
# # AUC: 64.80%
#
# # log_loss: 0.3426628423094844
#
# # AUC: 81.27%
#
# # log_loss: 0.20653568373213288
#
# # AUC: 71.81%
#
# # log_loss: 0.2866960834853927
#
# # AUC: 78.14%
#
# # log_loss: 0.21446280470853843
#
# # AUC: 85.70%
#
# # log_loss: 0.12264263720196733
#
# # AUC: 78.43%
#
# # log_loss: 0.23717781904455942
#
# # AUC: 84.90%
#
# # log_loss: 0.15919759595340574
#
# # AUC: 75.07%
#
# # log_loss: 0.28359018508298645
#
# # AUC: 82.99%
#
# # log_loss: 0.16380326951004265
#
# # AUC: 79.24%
#
# # log_loss: 0.2045800742591532
#
# ** mean AUC: 78.23%
#
# ** mean log_loss: 0.22213489952876633
#
# ========================================
# shunyi_aq
# 0    10115
# 1       51
# Name: test, dtype: int64
# # AUC: 63.85%
#
# # log_loss: 0.14226922235445827
#
# # AUC: 77.16%
#
# # log_loss: 0.07676406723238806
#
# # AUC: 67.33%
#
# # log_loss: 0.10604410790340246
#
# # AUC: 66.12%
#
# # log_loss: 0.11236878907935974
#
# # AUC: 66.88%
#
# # log_loss: 0.10703030832272732
#
# # AUC: 76.02%
#
# # log_loss: 0.08235148736318129
#
# # AUC: 77.74%
#
# # log_loss: 0.07843608831941755
#
# # AUC: 97.91%
#
# # log_loss: 0.014185135103428477
#
# # AUC: 99.04%
#
# # log_loss: 0.012821500727319721
#
# # AUC: 78.00%
#
# # log_loss: 0.07296236292650325
#
# ** mean AUC: 77.01%
#
# ** mean log_loss: 0.08052330693321862
#
# ========================================
# zhiwuyuan_aq
# 0    6566
# 1     253
# Name: test, dtype: int64
# # AUC: 80.56%
#
# # log_loss: 0.2943867572147287
#
# # AUC: 75.54%
#
# # log_loss: 0.3521854384993421
#
# # AUC: 81.74%
#
# # log_loss: 0.2893531193089695
#
# # AUC: 78.20%
#
# # log_loss: 0.33453402198887283
#
# # AUC: 88.63%
#
# # log_loss: 0.18518537801066629
#
# # AUC: 81.56%
#
# # log_loss: 0.32358355491351676
#
# # AUC: 88.67%
#
# # log_loss: 0.1497947527728621
#
# # AUC: 80.45%
#
# # log_loss: 0.32795681242716707
#
# # AUC: 89.81%
#
# # log_loss: 0.10571761474591096
#
# # AUC: 84.27%
#
# # log_loss: 0.24446713003820794
#
# ** mean AUC: 82.94%
#
# ** mean log_loss: 0.2607164579920244
#
# ========================================
# wanliu_aq
# 0    10117
# 1       90
# Name: test, dtype: int64
# # AUC: 91.32%
#
# # log_loss: 0.06048020215548024
#
# # AUC: 71.33%
#
# # log_loss: 0.15666488341470364
#
# # AUC: 80.31%
#
# # log_loss: 0.09607740404201716
#
# # AUC: 78.76%
#
# # log_loss: 0.11997607893118817
#
# # AUC: 79.00%
#
# # log_loss: 0.12403260154831625
#
# # AUC: 90.95%
#
# # log_loss: 0.059172597906189534
#
# # AUC: 85.66%
#
# # log_loss: 0.08665835532147464
#
# # AUC: 83.25%
#
# # log_loss: 0.09450190188567287
#
# # AUC: 84.90%
#
# # log_loss: 0.08988872380286358
#
# # AUC: 83.83%
#
# # log_loss: 0.09207340666456634
#
# ** mean AUC: 82.93%
#
# ** mean log_loss: 0.09795261556724724
#
# ========================================
# nongzhanguan_aq
# 0    9925
# 1     102
# Name: test, dtype: int64
# # AUC: 82.23%
#
# # log_loss: 0.12444543704326783
#
# # AUC: 96.21%
#
# # log_loss: 0.03443410428021278
#
# # AUC: 81.65%
#
# # log_loss: 0.1209157428754316
#
# # AUC: 92.19%
#
# # log_loss: 0.059293408275156154
#
# # AUC: 87.35%
#
# # log_loss: 0.0880086456200997
#
# # AUC: 97.93%
#
# # log_loss: 0.02726059259013617
#
# # AUC: 70.12%
#
# # log_loss: 0.19191874754244256
#
# # AUC: 80.60%
#
# # log_loss: 0.1280453754243624
#
# # AUC: 86.04%
#
# # log_loss: 0.09387666815836186
#
# # AUC: 84.76%
#
# # log_loss: 0.09742744359684515
#
# ** mean AUC: 85.91%
#
# ** mean log_loss: 0.09656261654063163
#
# ========================================
# mentougou_aq
# 0    10006
# 1       99
# Name: test, dtype: int64
# # AUC: 96.00%
#
# # log_loss: 0.031247083583854564
#
# # AUC: 92.29%
#
# # log_loss: 0.05347702304092735
#
# # AUC: 86.48%
#
# # log_loss: 0.09063489675661789
#
# # AUC: 86.55%
#
# # log_loss: 0.08659952731116634
#
# # AUC: 78.74%
#
# # log_loss: 0.12850022303813838
#
# # AUC: 79.51%
#
# # log_loss: 0.12427473775513025
#
# # AUC: 80.84%
#
# # log_loss: 0.12277217359050482
#
# # AUC: 91.29%
#
# # log_loss: 0.058024325545136465
#
# # AUC: 89.51%
#
# # log_loss: 0.06923321607275049
#
# # AUC: 85.04%
#
# # log_loss: 0.0878492233227643
#
# ** mean AUC: 86.63%
#
# ** mean log_loss: 0.08526124300169909
#
# ========================================
# pinggu_aq
# 0    9877
# 1     137
# Name: test, dtype: int64
# # AUC: 82.18%
#
# # log_loss: 0.1393875210838677
#
# # AUC: 80.68%
#
# # log_loss: 0.1164223379775655
#
# # AUC: 89.17%
#
# # log_loss: 0.05300612337924031
#
# # AUC: 67.81%
#
# # log_loss: 0.23855116937027826
#
# # AUC: 78.24%
#
# # log_loss: 0.16980386877027606
#
# # AUC: 70.82%
#
# # log_loss: 0.20647905894685917
#
# # AUC: 90.21%
#
# # log_loss: 0.07526290140333415
#
# # AUC: 68.81%
#
# # log_loss: 0.23292831935051353
#
# # AUC: 84.55%
#
# # log_loss: 0.10599879142568298
#
# # AUC: 78.04%
#
# # log_loss: 0.14417544187098094
#
# ** mean AUC: 79.05%
#
# ** mean log_loss: 0.14820155335785984
#
# ========================================
# liulihe_aq
# 0    7670
# 1     184
# Name: test, dtype: int64
# # AUC: 63.87%
#
# # log_loss: 0.39891630132845435
#
# # AUC: 76.71%
#
# # log_loss: 0.20326354097787272
#
# # AUC: 75.10%
#
# # log_loss: 0.24463888698929223
#
# # AUC: 79.63%
#
# # log_loss: 0.20321275217566714
#
# # AUC: 80.53%
#
# # log_loss: 0.19718689764224545
#
# # AUC: 83.69%
#
# # log_loss: 0.15290415413760924
#
# # AUC: 74.78%
#
# # log_loss: 0.2743483675168037
#
# # AUC: 69.35%
#
# # log_loss: 0.29008181158040447
#
# # AUC: 79.02%
#
# # log_loss: 0.2337543839680336
#
# # AUC: 74.55%
#
# # log_loss: 0.24703172667765722
#
# ** mean AUC: 75.72%
#
# ** mean log_loss: 0.24453388229940404
#
# ========================================
# huairou_aq
# 0    9876
# 1     117
# Name: test, dtype: int64
# # AUC: 83.46%
#
# # log_loss: 0.12741840859859604
#
# # AUC: 76.15%
#
# # log_loss: 0.16281947789098428
#
# # AUC: 87.35%
#
# # log_loss: 0.0981713607684967
#
# # AUC: 91.17%
#
# # log_loss: 0.06766592552427074
#
# # AUC: 83.38%
#
# # log_loss: 0.1283049379044573
#
# # AUC: 87.39%
#
# # log_loss: 0.08128598886898229
#
# # AUC: 78.03%
#
# # log_loss: 0.1613733675845174
#
# # AUC: 85.69%
#
# # log_loss: 0.09766964449576282
#
# # AUC: 82.89%
#
# # log_loss: 0.10941268969505624
#
# # AUC: 93.17%
#
# # log_loss: 0.05727276175671024
#
# ** mean AUC: 84.87%
#
# ** mean log_loss: 0.10913945630878341
#
# ========================================
# miyunshuiku_aq
# 0    9493
# 1     193
# Name: test, dtype: int64
# # AUC: 81.57%
#
# # log_loss: 0.22459818221097097
#
# # AUC: 90.47%
#
# # log_loss: 0.1197988015260538
#
# # AUC: 79.42%
#
# # log_loss: 0.25477802308958336
#
# # AUC: 94.14%
#
# # log_loss: 0.08349959952445023
#
# # AUC: 91.84%
#
# # log_loss: 0.09243301536302946
#
# # AUC: 80.10%
#
# # log_loss: 0.20314991075387012
#
# # AUC: 92.62%
#
# # log_loss: 0.08541722971447334
#
# # AUC: 91.45%
#
# # log_loss: 0.09690767563387574
#
# # AUC: 89.51%
#
# # log_loss: 0.12258283832008027
#
# # AUC: 86.85%
#
# # log_loss: 0.1538609690416091
#
# ** mean AUC: 87.80%
#
# ** mean log_loss: 0.14370262451779964
#
# ========================================
# xizhimenbei_aq
# 0    9809
# 1      77
# Name: test, dtype: int64
# # AUC: 96.39%
#
# # log_loss: 0.028558975608271277
#
# # AUC: 83.27%
#
# # log_loss: 0.08940465447907124
#
# # AUC: 82.44%
#
# # log_loss: 0.09309436799174751
#
# # AUC: 88.98%
#
# # log_loss: 0.05818379478933189
#
# # AUC: 75.15%
#
# # log_loss: 0.1238753363398018
#
# # AUC: 82.28%
#
# # log_loss: 0.08980349599138955
#
# # AUC: 80.90%
#
# # log_loss: 0.09456027949193492
#
# # AUC: 90.13%
#
# # log_loss: 0.05384354555610339
#
# # AUC: 56.36%
#
# # log_loss: 0.18821651978553117
#
# # AUC: 56.94%
#
# # log_loss: 0.18857457152506887
#
# ** mean AUC: 79.28%
#
# ** mean log_loss: 0.10081155415582517
#
# ========================================
# yanqin_aq
# 0    9932
# 1     192
# Name: test, dtype: int64
# # AUC: 88.75%
#
# # log_loss: 0.09125645142015044
#
# # AUC: 83.25%
#
# # log_loss: 0.15134979486398784
#
# # AUC: 80.89%
#
# # log_loss: 0.15891430032984571
#
# # AUC: 89.80%
#
# # log_loss: 0.09263802133919545
#
# # AUC: 88.77%
#
# # log_loss: 0.08856776624976158
#
# # AUC: 66.72%
#
# # log_loss: 0.2941613828757292
#
# # AUC: 71.39%
#
# # log_loss: 0.25273762324628263
#
# # AUC: 74.53%
#
# # log_loss: 0.21748875021819117
#
# # AUC: 76.23%
#
# # log_loss: 0.22036796258248384
#
# # AUC: 92.59%
#
# # log_loss: 0.08385804312039077
#
# ** mean AUC: 81.29%
#
# ** mean log_loss: 0.16513400962460187
#
# ========================================
# dongsi_aq
# 0    9962
# 1      74
# Name: test, dtype: int64
# # AUC: 91.96%
#
# # log_loss: 0.05131112362423852
#
# # AUC: 84.50%
#
# # log_loss: 0.08775932322236826
#
# # AUC: 77.43%
#
# # log_loss: 0.11749586148141755
#
# # AUC: 88.91%
#
# # log_loss: 0.06478703793362005
#
# # AUC: 90.28%
#
# # log_loss: 0.048524016101271286
#
# # AUC: 81.78%
#
# # log_loss: 0.0874101647425418
#
# # AUC: 66.38%
#
# # log_loss: 0.15108100750320386
#
# # AUC: 57.01%
#
# # log_loss: 0.1900394847522518
#
# # AUC: 90.50%
#
# # log_loss: 0.05371498796273419
#
# # AUC: 79.91%
#
# # log_loss: 0.09202323111939913
#
# ** mean AUC: 80.87%
#
# ** mean log_loss: 0.09441462384430464
#
# ========================================
# fengtaihuayuan_aq
# 0    9967
# 1     197
# Name: test, dtype: int64
# # AUC: 91.43%
#
# # log_loss: 0.09980453738825427
#
# # AUC: 94.21%
#
# # log_loss: 0.049156470255235986
#
# # AUC: 75.46%
#
# # log_loss: 0.27109381926947107
#
# # AUC: 79.68%
#
# # log_loss: 0.2087131257736847
#
# # AUC: 85.81%
#
# # log_loss: 0.14657007889658416
#
# # AUC: 88.17%
#
# # log_loss: 0.1352056605884377
#
# # AUC: 82.83%
#
# # log_loss: 0.1788446748354498
#
# # AUC: 82.62%
#
# # log_loss: 0.1746239999392923
#
# # AUC: 90.32%
#
# # log_loss: 0.08142779863376054
#
# # AUC: 87.66%
#
# # log_loss: 0.11552915831475039
#
# ** mean AUC: 85.82%
#
# ** mean log_loss: 0.14609693238949212
#
# ========================================
# tongzhou_aq
# 0    8988
# 1     152
# Name: test, dtype: int64
# # AUC: 70.59%
#
# # log_loss: 0.23868458022752714
#
# # AUC: 84.23%
#
# # log_loss: 0.12845823153785446
#
# # AUC: 68.71%
#
# # log_loss: 0.2669868666471016
#
# # AUC: 74.96%
#
# # log_loss: 0.1954257626228654
#
# # AUC: 81.67%
#
# # log_loss: 0.15304312982565976
#
# # AUC: 83.50%
#
# # log_loss: 0.12099214474105766
#
# # AUC: 77.16%
#
# # log_loss: 0.16249028831743456
#
# # AUC: 78.48%
#
# # log_loss: 0.16108889424753536
#
# # AUC: 81.56%
#
# # log_loss: 0.155211368581726
#
# # AUC: 81.64%
#
# # log_loss: 0.15603993121020474
#
# ** mean AUC: 78.25%
#
# ** mean log_loss: 0.17384211979589664
#
# ========================================
# donggaocun_aq
# 0    9623
# 1     114
# Name: test, dtype: int64
# # AUC: 82.20%
#
# # log_loss: 0.13235976387360013
#
# # AUC: 83.30%
#
# # log_loss: 0.13155535129153373
#
# # AUC: 85.38%
#
# # log_loss: 0.10266813838250739
#
# # AUC: 81.85%
#
# # log_loss: 0.1293200227114837
#
# # AUC: 77.15%
#
# # log_loss: 0.14134869561642066
#
# # AUC: 75.99%
#
# # log_loss: 0.16171694030661293
#
# # AUC: 80.93%
#
# # log_loss: 0.13361909805087113
#
# # AUC: 80.37%
#
# # log_loss: 0.13123984463844607
#
# # AUC: 69.88%
#
# # log_loss: 0.199710814494696
#
# # AUC: 89.40%
#
# # log_loss: 0.07216626792264455
#
# ** mean AUC: 80.64%
#
# ** mean log_loss: 0.1335704937288816
#
# ========================================
# miyun_aq
# 0    10034
# 1       90
# Name: test, dtype: int64
# # AUC: 84.68%
#
# # log_loss: 0.08672701899640696
#
# # AUC: 79.02%
#
# # log_loss: 0.12028013687837438
#
# # AUC: 84.28%
#
# # log_loss: 0.09090579044343362
#
# # AUC: 90.29%
#
# # log_loss: 0.06141764662074771
#
# # AUC: 93.34%
#
# # log_loss: 0.04689297383588679
#
# # AUC: 84.82%
#
# # log_loss: 0.09070377481407485
#
# # AUC: 79.93%
#
# # log_loss: 0.12285023575766113
#
# # AUC: 65.88%
#
# # log_loss: 0.18712787510951365
#
# # AUC: 86.38%
#
# # log_loss: 0.08842794708178911
#
# # AUC: 97.69%
#
# # log_loss: 0.02677973892534893
#
# ** mean AUC: 84.63%
#
# ** mean log_loss: 0.09221131384632371
#
# ========================================
# dingling_aq
# 0    10201
# 1       60
# Name: test, dtype: int64
# # AUC: 89.29%
#
# # log_loss: 0.046340588701083284
#
# # AUC: 81.18%
#
# # log_loss: 0.07812067913091911
#
# # AUC: 81.48%
#
# # log_loss: 0.07410709329335467
#
# # AUC: 87.29%
#
# # log_loss: 0.05357435584854954
#
# # AUC: 62.25%
#
# # log_loss: 0.14626241657753153
#
# # AUC: 97.86%
#
# # log_loss: 0.01661732526446578
#
# # AUC: 80.64%
#
# # log_loss: 0.07732593680087435
#
# # AUC: 63.40%
#
# # log_loss: 0.14342271662256506
#
# # AUC: 89.72%
#
# # log_loss: 0.04663755908923683
#
# # AUC: 90.13%
#
# # log_loss: 0.045362211321209746
#
# ** mean AUC: 82.32%
#
# ** mean log_loss: 0.07277708826497899
#
# ========================================
# yufa_aq
# 0    9596
# 1     199
# Name: test, dtype: int64
# # AUC: 73.99%
#
# # log_loss: 0.25926015365570854
#
# # AUC: 77.88%
#
# # log_loss: 0.19904790251816729
#
# # AUC: 77.65%
#
# # log_loss: 0.1955470127441903
#
# # AUC: 74.99%
#
# # log_loss: 0.25710141751611093
#
# # AUC: 79.09%
#
# # log_loss: 0.20195012415909414
#
# # AUC: 88.29%
#
# # log_loss: 0.12253741016640474
#
# # AUC: 79.53%
#
# # log_loss: 0.194648325946968
#
# # AUC: 78.91%
#
# # log_loss: 0.2034384511086795
#
# # AUC: 87.35%
#
# # log_loss: 0.14844205976721297
#
# # AUC: 72.00%
#
# # log_loss: 0.2612041488536176
#
# ** mean AUC: 78.97%
#
# ** mean log_loss: 0.20431770064361537
#
# ========================================
# fangshan_aq
# 0    10019
# 1      119
# Name: test, dtype: int64
# # AUC: 90.34%
#
# # log_loss: 0.06894808412564962
#
# # AUC: 82.88%
#
# # log_loss: 0.10481285721370018
#
# # AUC: 84.17%
#
# # log_loss: 0.1030356044083451
#
# # AUC: 80.54%
#
# # log_loss: 0.12928681056544788
#
# # AUC: 68.02%
#
# # log_loss: 0.22344481829605975
#
# # AUC: 75.09%
#
# # log_loss: 0.1621908744622079
#
# # AUC: 78.47%
#
# # log_loss: 0.15771585208096323
#
# # AUC: 81.15%
#
# # log_loss: 0.13111709353334683
#
# # AUC: 73.68%
#
# # log_loss: 0.16861044417874327
#
# # AUC: 75.26%
#
# # log_loss: 0.15815906916511072
#
# ** mean AUC: 78.96%
#
# ** mean log_loss: 0.14073215080295745
#
# ========================================
# tiantan_aq
# 0    9949
# 1     108
# Name: test, dtype: int64
# # AUC: 86.80%
#
# # log_loss: 0.09303165372591402
#
# # AUC: 86.77%
#
# # log_loss: 0.09385662062401262
#
# # AUC: 92.97%
#
# # log_loss: 0.05789326104822236
#
# # AUC: 92.92%
#
# # log_loss: 0.057897133527339606
#
# # AUC: 69.01%
#
# # log_loss: 0.19424790637016529
#
# # AUC: 68.97%
#
# # log_loss: 0.19630062143598365
#
# # AUC: 76.21%
#
# # log_loss: 0.1607775823733633
#
# # AUC: 72.43%
#
# # log_loss: 0.18682435173609901
#
# # AUC: 67.34%
#
# # log_loss: 0.19640741235587242
#
# # AUC: 84.63%
#
# # log_loss: 0.09230667567193132
#
# ** mean AUC: 79.81%
#
# ** mean log_loss: 0.13295432188689033
#
# ========================================
# yongledian_aq
# 0    9869
# 1      77
# Name: test, dtype: int64
# # AUC: 75.38%
#
# # log_loss: 0.12155167308908925
#
# # AUC: 53.34%
#
# # log_loss: 0.2224392321617909
#
# # AUC: 75.04%
#
# # log_loss: 0.11973704288509904
#
# # AUC: 74.72%
#
# # log_loss: 0.12079611482039568
#
# # AUC: 65.94%
#
# # log_loss: 0.1569407865576078
#
# # AUC: 66.12%
#
# # log_loss: 0.15702344253497746
#
# # AUC: 67.00%
#
# # log_loss: 0.15668263784257966
#
# # AUC: 61.97%
#
# # log_loss: 0.1562906255804239
#
# # AUC: 61.54%
#
# # log_loss: 0.15622322433723787
#
# # AUC: 89.33%
#
# # log_loss: 0.05360719548134307
#
# ** mean AUC: 69.04%
#
# ** mean log_loss: 0.14212919752905445
#
# ========================================
# pingchang_aq
# 0    10005
# 1      118
# Name: test, dtype: int64
# # AUC: 97.06%
#
# # log_loss: 0.03149662376560565
#
# # AUC: 88.33%
#
# # log_loss: 0.09441737361883663
#
# # AUC: 87.68%
#
# # log_loss: 0.09455006979846968
#
# # AUC: 89.41%
#
# # log_loss: 0.08600896553113736
#
# # AUC: 86.84%
#
# # log_loss: 0.10237684636083395
#
# # AUC: 87.27%
#
# # log_loss: 0.09596649735309261
#
# # AUC: 93.82%
#
# # log_loss: 0.05827960666302525
#
# # AUC: 84.47%
#
# # log_loss: 0.12626549313866003
#
# # AUC: 86.30%
#
# # log_loss: 0.09865124416205841
#
# # AUC: 74.82%
#
# # log_loss: 0.16897239572400277
#
# ** mean AUC: 87.60%
#
# ** mean log_loss: 0.09569851161157224
#
# ========================================
# badaling_aq
# 0    9994
# 1     171
# Name: test, dtype: int64
# # AUC: 92.95%
#
# # log_loss: 0.05731506754115771
#
# # AUC: 85.71%
#
# # log_loss: 0.1385616502957444
#
# # AUC: 93.37%
#
# # log_loss: 0.0706892891218369
#
# # AUC: 80.14%
#
# # log_loss: 0.17415551352251157
#
# # AUC: 93.31%
#
# # log_loss: 0.07336414547581804
#
# # AUC: 78.49%
#
# # log_loss: 0.20702723130379302
#
# # AUC: 88.75%
#
# # log_loss: 0.11052161160775843
#
# # AUC: 85.89%
#
# # log_loss: 0.1393373252034903
#
# # AUC: 95.84%
#
# # log_loss: 0.04396456973338911
#
# # AUC: 91.32%
#
# # log_loss: 0.07367644830043113
#
# ** mean AUC: 88.58%
#
# ** mean log_loss: 0.10886128521059306
#
# ========================================

# %% [markdown]
# That is to say not all AQI station has the uniform distribution of the missing value. But some have!!

# %% [markdown]
# # Level two adverserial detection

# %% [markdown]
# ### Preprocessing
# #### binding by time slice, time slice( time stamp) align

# %%
start=time.time()
a = set(beijing_grid_sta.groupby(["utc_time"]).groups.keys())
b = set(beji_aqi_summary.groupby(["utc_time"]).groups.keys())
exclusive=(a ^ b)
beijing_grid_sta_copy=beijing_grid_sta.copy() #a
beji_aqi_summary_copy=beji_aqi_summary.copy() #b
first_time_1=1
first_time_2=1
for timeslice in exclusive:
    if timeslice in a:
        if first_time_1 is 1:
            first_time_1=0
            contaniner_1=np.array(beijing_grid_sta.groupby(["utc_time"]).groups[timeslice])
        else:
            new=np.array(beijing_grid_sta.groupby(["utc_time"]).groups[timeslice])
            contaniner_1=np.append(contaniner_1,new)
    else:
        if first_time_2 is 1:
            first_time_2=0
            contaniner_2=np.array(beji_aqi_summary.groupby(["utc_time"]).groups[timeslice])
        else:
            new=np.array(beji_aqi_summary.groupby(["utc_time"]).groups[timeslice])
            contaniner_2=np.append(contaniner_2,new)

contaniner_1=np.sort(contaniner_1) 
contaniner_2=np.sort(contaniner_2) 
end=time.time()
print("cost time:"+ str(end-start))

# %%
import pickle
pickle.dump(contaniner_1,open("Beijin_grid_station(drop index).pkl", "wb"))
pickle.dump(contaniner_2,open("Beijin_AQI_station(drop index).pkl", "wb"))

# %%
beijing_grid_sta.drop(contaniner_1)

# %%
beijing_grid_sta=beijing_grid_sta.drop(contaniner_1)

# %%
beji_aqi_summary_copy=beji_aqi_summary_copy.drop(contaniner_2)

# %%
beijing_grid_sta.columns
# Out:
# Index(['stationName', 'longitude', 'latitude', 'utc_time', 'temperature',
#        'pressure', 'humidity', 'wind_direction', 'wind_speed/kph'],
#       dtype='object')

# %%
col=['utc_time', 'temperature',
       'pressure', 'humidity', 'wind_direction', 'wind_speed/kph']
gp=beijing_grid_sta[col].groupby(by=["utc_time"])

# 2018-03-26 13:00:00        8.513395
# 2018-03-26 14:00:00        8.112304
# 2018-03-26 15:00:00        7.974716
# 2018-03-26 16:00:00        7.761413
# 2018-03-26 17:00:00        7.666667
# 2018-03-26 18:00:00        7.685484
# 2018-03-26 19:00:00        7.412949
# 2018-03-26 20:00:00        7.189339
# 2018-03-26 21:00:00        7.019908
# 2018-03-26 22:00:00        6.884117
# 2018-03-26 23:00:00        6.828648
# 2018-03-27 00:00:00        6.861321
# 2018-03-27 01:00:00        8.460630
# 2018-03-27 02:00:00       10.783518
# 2018-03-27 03:00:00       13.303932
# 2018-03-27 04:00:00       15.976452
# 2018-03-27 05:00:00       19.052688
#
# [10007 rows x 5 columns]

# %%
beijing_grid_sta.merge(gp, on=["utc_time"], how='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-888ccfd1674f> in <module>()
# ----> 1 beijing_grid_sta.merge(gp, on=["utc_time"], how='left')
#
# ~/.local/lib/python3.5/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    5368                      right_on=right_on, left_index=left_index,
#    5369                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 5370                      copy=copy, indicator=indicator, validate=validate)
#    5371
#    5372     def round(self, decimals=0, *args, **kwargs):
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# ~/.local/lib/python3.5/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     539         if not isinstance(right, DataFrame):
#     540             raise ValueError('can not merge DataFrame with instance of '
# --> 541                              'type {right}'.format(right=type(right)))
#     542
#     543         if not is_bool(left_index):
#
# ValueError: can not merge DataFrame with instance of type <class 'pandas.core.groupby.DataFrameGroupBy'>

# %%
beijing_grid_sta.groupby(["utc_time"]).groups[timeslice]
# Out:
# Int64Index([5123370, 5123371, 5123372, 5123373, 5123374, 5123375, 5123376,
#             5123377, 5123378, 5123379,
#             ...
#             5124011, 5124012, 5124013, 5124014, 5124015, 5124016, 5124017,
#             5124018, 5124019, 5124020],
#            dtype='int64', length=651)

# %%
type(beijing_grid_sta.groupby(["utc_time"]).groups[timeslice])
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
np.array(beijing_grid_sta.groupby(["utc_time"]).groups[timeslice])
# Out:
# array([5123370, 5123371, 5123372, 5123373, 5123374, 5123375, 5123376,
#        5123377, 5123378, 5123379, 5123380, 5123381, 5123382, 5123383,
#        5123384, 5123385, 5123386, 5123387, 5123388, 5123389, 5123390,
#        5123391, 5123392, 5123393, 5123394, 5123395, 5123396, 5123397,
#        5123398, 5123399, 5123400, 5123401, 5123402, 5123403, 5123404,
#        5123405, 5123406, 5123407, 5123408, 5123409, 5123410, 5123411,
#        5123412, 5123413, 5123414, 5123415, 5123416, 5123417, 5123418,
#        5123419, 5123420, 5123421, 5123422, 5123423, 5123424, 5123425,
#        5123426, 5123427, 5123428, 5123429, 5123430, 5123431, 5123432,
#        5123433, 5123434, 5123435, 5123436, 5123437, 5123438, 5123439,
#        5123440, 5123441, 5123442, 5123443, 5123444, 5123445, 5123446,
#        5123447, 5123448, 5123449, 5123450, 5123451, 5123452, 5123453,
#        5123454, 5123455, 5123456, 5123457, 5123458, 5123459, 5123460,
